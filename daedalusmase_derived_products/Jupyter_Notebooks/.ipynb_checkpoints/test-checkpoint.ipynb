# %%
#import required packages
import sys
from netCDF4 import Dataset
import numpy as np
import datetime
import pyglow
from ipywidgets import*
import ipywidgets as widgets
import warnings
import glob
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from mpl_toolkits.basemap import Basemap, shiftgrid, addcyclic
import matplotlib.mlab as mlab
from mpl_toolkits.axes_grid1 import make_axes_locatable
from scipy.interpolate import griddata
from pylab import *
from matplotlib.patches import Polygon
import time
import pandas as pd
from scipy.special import erf
import matplotlib.colors as colors
from matplotlib import ticker, cm

#Define WPIT package location
current_dir =  os.path.abspath(os.path.dirname('__file__'))
fpath = os.path.abspath(current_dir + "/..")
sys.path.append(fpath)
sys.path.append(current_dir)

#import sub_Collision_Freqs_Cross_Sections sub-module
import DaedalusMASE_Derived_Products.sub_Collision_Freqs_Cross_Sections as cols

#import sub_Conductivities sub-module
import DaedalusMASE_Derived_Products.sub_Conductivities as cond

#import sub_coords_utils sub-module
import DaedalusMASE_Derived_Products.sub_coords_utils as coords

#import sub_Currents_Magnetic_Forcing sub-module
import DaedalusMASE_Derived_Products.sub_Currents_Magnetic_Forcing as currents

#import sub_Heating_Sources sub-module
import DaedalusMASE_Derived_Products.sub_Heating_Sources as heatings


#import sub_Heating_Sources sub-module
import DaedalusMASE_Derived_Products.sub_tiegcm_utils as tiegcm


#Allocations
Ohmic1=[]
zg1=[]
Joule1=[]
Frictional1=[]
nO1=[]
nO21=[]
nN21=[]
Ne1=[]
NOp1=[]
NO2p1=[]
sigmaHall1=[]
sigmaPed1=[]
sigmaHall1TIEGCM=[]
sigmaPed1TIEGCM=[]
sigma01=[]
omega_e1=[]
omega_Op1=[]
vOp1=[]
ven1=[]
omega_O2p1=[]
JH_rhov=[]
vNOp1=[]
NNOp1=[]
omega_NOp1=[]
vO2p1=[]
vin1=[]
vi_op_x1=[]
vi_op_y1=[]
vi_op_z1=[]
vi_o2p_x1=[]
vi_o2p_y1=[]
vi_o2p_z1=[]
vi_nop_x1=[]
vi_nop_y1=[]
vi_nop_z1=[]
unvx1=[]
unvy1=[]
unvz1=[]
ExBx1=[]
ExBy1=[]
ExBz1=[]
ve_x1=[]
ve_y1=[]
ve_z1=[]
E_e=[]
E_n=[]
E_u=[]
J_pe=[]
J_pn=[]
J_pu=[]
J_he=[]
J_hn=[]
J_hu=[]
T_e=[]
T_i=[]
T_n=[]
J_p_Ohmice=[]
J_p_Ohmicn=[]
J_p_Ohmicu=[]
J_dene=[]
J_denn=[]
J_denu=[]
cross_sectionf=[]
Pressure=[]
ohmic_pressure=[]
pressure_ohmic=[]
lat_out=[]
lon_out=[]
wind1=[]
convection1=[]
ohms_ohmic=[]
Ee_TIEGCM1=[]
En_TIEGCM1=[]
Eu_TIEGCM1=[]
QAMIE1=[]
QWIND1=[]
cross_op_sectionf=[]
cross_nop_sectionf=[]
cross_o2p_sectionf=[]
qDTop_o=[]
qDTop_o2=[]
qDTop_n2=[]
qDTop_he=[]
qDTo2p_o=[]
qDTo2p_o2=[]
qDTo2p_n2=[]
qDTo2p_he=[]
qDTnop_o=[]
qDTnop_o2=[]
qDTnop_n2=[]
qDTnop_he=[]
qDTop_n=[]
qDTo2p_n=[]
qDTnop_n=[]
qDTi_n=[]
Argon=[]
Helium=[]
NitricOxide=[]
Nitrogen_ion=[]
Le_N2_rot=[]
Le_O2_rot=[]
Le_O_fine=[]
Le_N2_vib=[]
Le_O_1D=[]
Le_O2_vib=[]
qDTe_o=[]
qDTe_o2=[]
qDTe_n2=[]
qDTe_he=[]
qDTe_n=[]
Le1=[]
vei=[]
qDTe_op=[]
qDTe_o2p=[]
qDTe_np=[]
qDTe_nop=[]
qDTe_i=[]
vop_n_SB=[]
vo2p_n_SB=[]

Nef=np.zeros((72, 144),order='F')
NOf=np.zeros((72, 144),order='F')
NO2f=np.zeros((72, 144),order='F')
NN2f=np.zeros((72, 144),order='F')
NNOpf=np.zeros((72, 144),order='F')
Evert=np.zeros((72, 144),order='F')
Evertx=np.zeros((72, 144),order='F')
Everty=np.zeros((72, 144),order='F')
Evertz=np.zeros((72, 144),order='F')
NOpf=np.zeros((72, 144),order='F')
NO2pf=np.zeros((72, 144),order='F')
Omega_ef=np.zeros((72, 144),order='F')
Omega_Opf=np.zeros((72, 144),order='F')
vOpf=np.zeros((72, 144),order='F')
venf=np.zeros((72, 144),order='F')
sigmaPedf=np.zeros((72, 144),order='F')
sigmaPedf_T=np.zeros((72, 144),order='F')
sigmaHallf=np.zeros((72, 144),order='F')
sigmaHallf_T=np.zeros((72, 144),order='F')
TIEGCM_PEDf=np.zeros((72, 144),order='F')
TIEGCM_HALLf=np.zeros((72, 144),order='F')
Potf=np.zeros((72, 144),order='F')
vi_starxf_op=np.zeros((72, 144),order='F')
vi_staryf_op=np.zeros((72, 144),order='F')
vi_starzf_op=np.zeros((72, 144),order='F')
vi_starxf_o2p=np.zeros((72, 144),order='F')
vi_staryf_o2p=np.zeros((72, 144),order='F')
vi_starzf_o2p=np.zeros((72, 144),order='F')
vi_starxf_nop=np.zeros((72, 144),order='F')
vi_staryf_nop=np.zeros((72, 144),order='F')
vi_starzf_nop=np.zeros((72, 144),order='F')
Bxf=np.zeros((72, 144),order='F')
Byf=np.zeros((72, 144),order='F')
Bzf=np.zeros((72, 144),order='F')
zgf=np.zeros((72, 144),order='F')
Ohmic=np.zeros((72, 144),order='F')
Joule=np.zeros((72, 144),order='F')
Frictional=np.zeros((72, 144),order='F')
Ohmic_TIEGCM=np.zeros((72, 144),order='F')
unvertxf=np.zeros((72, 144),order='F')
unvertyf=np.zeros((72, 144),order='F')
unvertzf=np.zeros((72, 144),order='F')
ExB_x=np.zeros((72, 144),order='F')
ExB_y=np.zeros((72, 144),order='F')
ExB_z=np.zeros((72, 144),order='F')
ExBx_calc=np.zeros((72, 144),order='F')
ExBy_calc=np.zeros((72, 144),order='F')
ExBz_calc=np.zeros((72, 144),order='F')
NO2pf=np.zeros((72, 144),order='F')
Omega_NOpf=np.zeros((72, 144),order='F')
Omega_O2pf=np.zeros((72, 144),order='F')
vO2pf=np.zeros((72, 144),order='F')
vinf=np.zeros((72, 144),order='F')
JH_rho=np.zeros((72, 144),order='F')
sigma_par=np.zeros((72, 144),order='F')
J_densx=np.zeros((72, 144),order='F')
J_densy=np.zeros((72, 144),order='F')
J_densz=np.zeros((72, 144),order='F')
J_Ohmx=np.zeros((72, 144),order='F')
J_Ohmy=np.zeros((72, 144),order='F')
J_Ohmz=np.zeros((72, 144),order='F')
vee_out=np.zeros((72, 144),order='F')
ven_out=np.zeros((72, 144),order='F')
veu_out=np.zeros((72, 144),order='F')
maplat=np.zeros((72),order='F')
maplon=np.zeros((144),order='F')
maptime=np.zeros((24),order='F')
J_Pede=np.zeros((72, 144),order='F')
J_Pedn=np.zeros((72, 144),order='F')
J_Pedu=np.zeros((72, 144),order='F')
J_Halle=np.zeros((72, 144),order='F')
J_Halln=np.zeros((72, 144),order='F')
J_Hallu=np.zeros((72, 144),order='F')
J_Ohme=np.zeros((72, 144),order='F')
J_Ohmn=np.zeros((72, 144),order='F')
J_Ohmu=np.zeros((72, 144),order='F')
vi_mag_op=np.zeros((72, 144),order='F')
vi_mag_o2p=np.zeros((72, 144),order='F')
vi_mag_nop=np.zeros((72, 144),order='F')
J_mag=np.zeros((72, 144),order='F')
Unef=np.zeros((72, 144),order='F')
Unnf=np.zeros((72, 144),order='F')
Unuf=np.zeros((72, 144),order='F')
JxBe=np.zeros((72, 144),order='F')
JxBn=np.zeros((72, 144),order='F')
JxBu=np.zeros((72, 144),order='F')
QAMIE_T=np.zeros((72, 144),order='F')
QWIND_T=np.zeros((72, 144),order='F')
Ti_Out=np.zeros((72, 144),order='F')
Te_Out=np.zeros((72, 144),order='F')
Tn_Out=np.zeros((72, 144),order='F')
Press_Ohmic=np.zeros((72, 144),order='F')
cross_section=np.zeros((72, 144),order='F')
cross_section_op=np.zeros((72, 144),order='F')
cross_section_o2p=np.zeros((72, 144),order='F')
cross_section_nop=np.zeros((72, 144),order='F')
Convenction_heating_Out=np.zeros((72, 144),order='F')
Wind_heating_Out=np.zeros((72, 144),order='F')
Ohmic_heating_OhmsLaw_Out=np.zeros((72, 144),order='F')
Mechanical_power_Out=np.zeros((72, 144),order='F')
Energy_Out=np.zeros((72, 144),order='F')
Pressure_2D=np.zeros((72, 144),order='F')
Ohmic_Press=np.zeros((72, 144),order='F')
vNOpf=np.zeros((72, 144),order='F')
qDTop_of=np.zeros((72, 144),order='F')
qDTop_o2f=np.zeros((72, 144),order='F')
qDTop_n2f=np.zeros((72, 144),order='F')
qDTo2p_of=np.zeros((72, 144),order='F')
qDTo2p_o2f=np.zeros((72, 144),order='F')
qDTo2p_n2f=np.zeros((72, 144),order='F')
qDTnop_of=np.zeros((72, 144),order='F')
qDTnop_o2f=np.zeros((72, 144),order='F')
qDTnop_n2f=np.zeros((72, 144),order='F')
qDTop_nf=np.zeros((72, 144),order='F')
qDTo2p_nf=np.zeros((72, 144),order='F')
qDTnop_nf=np.zeros((72, 144),order='F')
qDTi_nf=np.zeros((72, 144),order='F')
Le_N2_rot_2d=np.zeros((72, 144),order='F')
Le_O2_rot_2d=np.zeros((72, 144),order='F')
Le_O2_vib_2d=np.zeros((72, 144),order='F')
Le_O_fine_2d=np.zeros((72, 144),order='F')
Le_N2_vib_2d=np.zeros((72, 144),order='F')
Le_O_1D_2d=np.zeros((72, 144),order='F')
Le_all_2d=np.zeros((72, 144),order='F')
qDTe_o_2d=np.zeros((72, 144),order='F')
qDTe_o2_2d=np.zeros((72, 144),order='F')
qDTe_n2_2d=np.zeros((72, 144),order='F')
qDTe_he_2d=np.zeros((72, 144),order='F')
qDTe_op_2d=np.zeros((72, 144),order='F')
qDTe_o2p_2d=np.zeros((72, 144),order='F')
qDTe_nop_2d=np.zeros((72, 144),order='F')
qDTe_np_2d=np.zeros((72, 144),order='F')
qDTe_i_2d=np.zeros((72, 144),order='F')
qDTe_n_2d=np.zeros((72, 144),order='F')

Nefl=np.zeros((57, 72),order='F')
NOfl=np.zeros((57, 72),order='F')
NO2fl=np.zeros((57, 72),order='F')
NN2fl=np.zeros((57, 72),order='F')
NNOpfl=np.zeros((57, 72),order='F')
Evertl=np.zeros((57, 72),order='F')
Evertxl=np.zeros((57, 72),order='F')
Evertyl=np.zeros((57, 72),order='F')
Evertzl=np.zeros((57, 72),order='F')
NOpfl=np.zeros((57, 72),order='F')
NO2pfl=np.zeros((57, 72),order='F')
Omega_efl=np.zeros((57, 72),order='F')
Omega_Opfl=np.zeros((57, 72),order='F')
vOpfl=np.zeros((57, 72),order='F')
venfl=np.zeros((57, 72),order='F')
sigmaPedfl=np.zeros((57, 72),order='F')
sigmaPedf_Tl=np.zeros((57, 72),order='F')
sigmaHallfl=np.zeros((57, 72),order='F')
sigmaHallf_Tl=np.zeros((57, 72),order='F')
TIEGCM_PEDfl=np.zeros((57, 72),order='F')
TIEGCM_HALLfl=np.zeros((57, 72),order='F')
Potfl=np.zeros((57, 72),order='F')
vi_starxf_opl=np.zeros((57, 72),order='F')
vi_staryf_opl=np.zeros((57, 72),order='F')
vi_starzf_opl=np.zeros((57, 72),order='F')
vi_starxf_o2pl=np.zeros((57, 72),order='F')
vi_staryf_o2pl=np.zeros((57, 72),order='F')
vi_starzf_o2pl=np.zeros((57, 72),order='F')
vi_starxf_nopl=np.zeros((57, 72),order='F')
vi_staryf_nopl=np.zeros((57, 72),order='F')
vi_starzf_nopl=np.zeros((57, 72),order='F')
Bxfl=np.zeros((57, 72),order='F')
Byfl=np.zeros((57, 72),order='F')
Bzfl=np.zeros((57, 72),order='F')
zgfl=np.zeros((57, 72),order='F')
Ohmicl=np.zeros((57, 72),order='F')
Joulel=np.zeros((57, 72),order='F')
Frictionall=np.zeros((57, 72),order='F')
Ohmic_TIEGCMl=np.zeros((57, 72),order='F')
unvertxfl=np.zeros((57, 72),order='F')
unvertyfl=np.zeros((57, 72),order='F')
unvertzfl=np.zeros((57, 72),order='F')
ExB_xl=np.zeros((57, 72),order='F')
ExB_yl=np.zeros((57, 72),order='F')
ExB_zl=np.zeros((57, 72),order='F')
ExBx_calcl=np.zeros((57, 72),order='F')
ExBy_calcl=np.zeros((57, 72),order='F')
ExBz_calcl=np.zeros((57, 72),order='F')
NO2pfl=np.zeros((57, 72),order='F')
Omega_NOpfl=np.zeros((57, 72),order='F')
Omega_O2pfl=np.zeros((57, 72),order='F')
vO2pfl=np.zeros((57, 72),order='F')
vinfl=np.zeros((57, 72),order='F')
JH_rhol=np.zeros((57, 72),order='F')
sigma_parl=np.zeros((57, 72),order='F')
J_densxl=np.zeros((57, 72),order='F')
J_densyl=np.zeros((57, 72),order='F')
J_denszl=np.zeros((57, 72),order='F')
J_Ohmxl=np.zeros((57, 72),order='F')
J_Ohmyl=np.zeros((57, 72),order='F')
J_Ohmzl=np.zeros((57, 72),order='F')
vee_outl=np.zeros((57, 72),order='F')
ven_outl=np.zeros((57, 72),order='F')
veu_outl=np.zeros((57, 72),order='F')
maplatl=np.zeros((72),order='F')
# maplon1=np.zeros((144),order='F')
mapaltl=np.zeros((57),order='F')
maptimel=np.zeros((24),order='F')
J_Pedel=np.zeros((57, 72),order='F')
J_Pednl=np.zeros((57, 72),order='F')
J_Pedul=np.zeros((57, 72),order='F')
J_Hallel=np.zeros((57, 72),order='F')
J_Hallnl=np.zeros((57, 72),order='F')
J_Hallul=np.zeros((57, 72),order='F')
J_Ohmel=np.zeros((57, 72),order='F')
J_Ohmnl=np.zeros((57, 72),order='F')
J_Ohmul=np.zeros((57, 72),order='F')
vi_mag_opl=np.zeros((57, 72),order='F')
vi_mag_o2pl=np.zeros((57, 72),order='F')
vi_mag_nopl=np.zeros((57, 72),order='F')
J_magl=np.zeros((57, 72),order='F')
Unefl=np.zeros((57, 72),order='F')
Unnfl=np.zeros((57, 72),order='F')
Unufl=np.zeros((57, 72),order='F')
JxBel=np.zeros((57, 72),order='F')
JxBnl=np.zeros((57, 72),order='F')
JxBul=np.zeros((57, 72),order='F')
QAMIE_Tl=np.zeros((57, 72),order='F')
QWIND_Tl=np.zeros((57, 72),order='F')
Ti_Outl=np.zeros((57, 72),order='F')
Te_Outl=np.zeros((57, 72),order='F')
Tn_Outl=np.zeros((57, 72),order='F')
Press_Ohmicl=np.zeros((57, 72),order='F')
cross_sectionl=np.zeros((57, 72),order='F')
cross_section_opl=np.zeros((57, 72),order='F')
cross_section_o2pl=np.zeros((57, 72),order='F')
cross_section_nopl=np.zeros((57, 72),order='F')
Convenction_heating_Outl=np.zeros((57, 72),order='F')
Wind_heating_Outl=np.zeros((57, 72),order='F')
Ohmic_heating_OhmsLaw_Outl=np.zeros((57, 72),order='F')
Mechanical_power_Outl=np.zeros((57, 72),order='F')
Energy_Outl=np.zeros((57, 72),order='F')
Pressure_2Dl=np.zeros((57, 72),order='F')
Ohmic_Pressl=np.zeros((57, 72),order='F')
vNOpfl=np.zeros((57, 72),order='F')
qDTop_ofl=np.zeros((57, 72),order='F')
qDTop_o2fl=np.zeros((57, 72),order='F')
qDTop_n2fl=np.zeros((57, 72),order='F')
qDTo2p_ofl=np.zeros((57, 72),order='F')
qDTo2p_o2fl=np.zeros((57, 72),order='F')
qDTo2p_n2fl=np.zeros((57, 72),order='F')
qDTnop_ofl=np.zeros((57, 72),order='F')
qDTnop_o2fl=np.zeros((57, 72),order='F')
qDTnop_n2fl=np.zeros((57, 72),order='F')
qDTop_nfl=np.zeros((57, 72),order='F')
qDTo2p_nfl=np.zeros((57, 72),order='F')
qDTnop_nfl=np.zeros((57, 72),order='F')
qDTi_nfl=np.zeros((57, 72),order='F')

#Transformation from ENU to ECEF
def enu_ecef(lat_phi, lon_lmd, Fe, Fn, Fup):
    fac = np.pi / 180
    lat_phi = lat_phi * fac
    lon_lmd = lon_lmd * fac

    north_temp_unit = [-np.cos(lon_lmd) * np.sin(lat_phi), - np.sin(lon_lmd) * np.sin(lat_phi), np.cos(lat_phi)]
    east_temp_unit = [-np.sin(lon_lmd), np.cos(lon_lmd), 0]
    up_temp_unit = [np.cos(lon_lmd) * np.cos(lat_phi), np.sin(lon_lmd) * np.cos(lat_phi), np.sin(lat_phi)]

    Fnorth_vector = [Fn * north_temp_unit[0], Fn * north_temp_unit[1], Fn * north_temp_unit[2]]
    Feast_vector = [Fe * east_temp_unit[0], Fe * east_temp_unit[1], Fe * east_temp_unit[2]]
    Fup_vector = [Fup * up_temp_unit[0], Fup * up_temp_unit[1], Fup * up_temp_unit[2]]

    Fx = Fnorth_vector[0] + Feast_vector[0] + Fup_vector[0]
    Fy = Fnorth_vector[1] + Feast_vector[1] + Fup_vector[1]
    Fz = Fnorth_vector[2] + Feast_vector[2] + Fup_vector[2]

    return Fx, Fy, Fz

#Transformation from ECEF to ENU
def ecef_enu(lat_phi, lon_lmd, Fx, Fy, Fz):
    fac = np.pi / 180
    lat_phi = lat_phi * fac
    lon_lmd = lon_lmd * fac
    
    x_temp_unit=[-np.sin(lon_lmd), -np.cos(lon_lmd)*np.sin(lat_phi),np.cos(lon_lmd)*np.cos(lat_phi)]
    y_temp_unit=[np.cos(lon_lmd),-np.sin(lon_lmd)*np.sin(lat_phi),np.sin(lon_lmd)*np.cos(lat_phi)]
    z_temp_unit=[0, np.cos(lat_phi),np.sin(lat_phi)]

    Fx_vector = [Fx * x_temp_unit[0], Fx * x_temp_unit[1], Fx * x_temp_unit[2]]
    Fy_vector = [Fy * y_temp_unit[0], Fy * y_temp_unit[1], Fy * y_temp_unit[2]]
    Fz_vector = [Fz * z_temp_unit[0], Fz * z_temp_unit[1], Fz * z_temp_unit[2]]

    Fe = Fx_vector[0] + Fy_vector[0] + Fz_vector[0]
    Fn = Fx_vector[1] + Fy_vector[1] + Fz_vector[1]
    Fu = Fx_vector[2] + Fy_vector[2] + Fz_vector[2]

    return Fe, Fn, Fu

 # calculate geocentric latitude from geodetic latitude (WGS84)
def geo_lat2geod_lat(phi):
    a = 6378137  # meter semi major axis of earth
    f = 1 / 298.257  # flattening
    b = a - f * a  # semi minor axis
    e = ((a ** 2 - b ** 2) ** (1 / 2)) / a
    phi_rad = np.deg2rad(phi)
    geod_lat = np.arctan(np.tan(phi_rad) / (1 - e ** 2))
    geod_lat = np.rad2deg(geod_lat)
    return geod_lat  # in degrees

#Geographic to Geodetic transformation
def geo2geod(lat_geo_phi, lon_geo_lmd, alt_geo):
    lat_geod_phi = geo_lat2geod_lat(lat_geo_phi)  # degrees
    lon_geod_lmd = lon_geo_lmd  # degrees
    alt_geod = alt_geo  # km
    return lat_geod_phi, lon_geod_lmd, alt_geod

#Calculation of products for map plotting
def run_map(tiegcm_file,timer_value,pressure_level):
    # Initializations
    warnings.simplefilter('ignore')
    
    start_time = time.time()
    time_igrf = datetime.datetime(2015, 3, 15, 0, 0, 0)  # first time step of the TIEGCM run
    timer = 0  # counter used for incrementing TIEGCM timestep
    deltalmd = 2.5  # TIEGCM grid resolution in deg
    deltaphi = 2.5  # TIEGCM grid resolution in deg
    Re = 6378.1370  # Earths Radius (km)
    electron = 1.602176565 * 10 ** (- 19) #electron charge in C
    boltzmann_si=1.38064852 * 10**(-23)
    boltzmann=1.380645852 * 10 ** (-16) #Boltzmann constant in cm^2*g*s^(-2)*K^(-1)
    me=9.10938356 * 10 ** (- 31) #electron mass in kg
    mO=16 # Oxygen atomic mass in g/mol
    mN2=28  #N2 molecular mass in g/mol
    mO2=32 #O2 molecular mass in g/mol
    mNO=30 #NO molecular mass in g/mol
    NA=6.02214086 * 10 ** 23 #Avogadro's constant in mol^-1
    fcor=1.5 #Burnside facor (default=1.5)
    
    #Input file
    TIEGCM = Dataset(tiegcm_file)

    # Get data from TIEGCM Model file
    glat = TIEGCM.variables['lat'][:] #geographic latitude in deg
    glon = TIEGCM.variables['lon'][:] #geographic longitude in deg
    glev = TIEGCM.variables['lev'][:] #interface levels
    gtime = TIEGCM.variables['time'][:] #time in minutes since 2015 March 15 00:00:00
    zg = TIEGCM.variables['ZGMID'][:] #Geometric height in cm
    Ne_all = TIEGCM.variables['NE'][:]  # electron density in cm^-3
    Ne_mid = TIEGCM.variables['ELECDEN'][:]  # electron density in cm^-3
    Un_east = TIEGCM.variables['UN'][:]  # neutral zonal wind (+East) in cm/s
    Un_north = TIEGCM.variables['VN'][:]  # neutral meridional wind (+North) in cm/s
    Un_up = TIEGCM.variables['WN_lev'][:]  # neutral vertical wind (+Up) in cm/s
    Ui_east = TIEGCM.variables['Ui_lev'][:]  # zonal ExB velocity in cm/s
    Ui_north = TIEGCM.variables['Vi_lev'][:]  # meridional ExB velocity in cm/s
    Ui_up = TIEGCM.variables['Wi_lev'][:]  # vertical ExB velocity in cm/s
    Poten_all=TIEGCM.variables['POTEN'][:] #electric potential in V
    barm_all=TIEGCM.variables['BARM'][:] #Mean molecular weight in g/mol
    P0=TIEGCM.variables['p0'][:] #Reference pressure in millibar
    Zh=TIEGCM.variables['Z'][:] #dimensionless variable (for pressure calculations)
    Tn_all=TIEGCM.variables['TN'][:] #Neutral Temperature in K
    Te_all=TIEGCM.variables['TE'][:] #Electron Temperature in K
    Ti_all=TIEGCM.variables['TI'][:] #Ion Temperature in K
    nO_all=TIEGCM.variables['O1'][:] #neutral atomic oxygen density in mmr
    nO2_all=TIEGCM.variables['O2'][:] #neutral molecular oxygen density in mmr
    NOp_all=TIEGCM.variables['OP'][:] #O+ density in cm^-3
    den_all=TIEGCM.variables['DEN'][:] #Density
    nO_all_cm3=TIEGCM.variables['O_CM3'][:] #neutral atomic oxygen density in mmr
    nO2_all_cm3=TIEGCM.variables['O2_CM3'][:] #neutral molecular oxygen density in mmr
    NO2p_all=TIEGCM.variables['O2P'][:] #O+ density in cm^-3
    Np_all=TIEGCM.variables['NPLUS'][:] #N+ density in cm^-3
    NNOp_all=TIEGCM.variables['NOP_LAM'][:] #NO+ density in cm^-3
    N2_all_cm3=TIEGCM.variables['N2_CM3'][:] #N2 density in cm^-3
    EEX=TIEGCM.variables['EEX'][:] 
    EEY=TIEGCM.variables['EEY'][:] 
    EEZ=TIEGCM.variables['EEZ'][:] 
    Helium_all=TIEGCM.variables['HE'][:]
    TIEGCM.close() #close input file

    for timer in range(timer_value,timer_value+1):
        time_plot=gtime[timer]
        maptime[timer]=time_plot
        
        for lev in range(pressure_level, pressure_level+1):
        
            for lat in range(0, len(glat)):

                for lon in range(0, len(glon)):
                    
                    ########################################################################
#                   Coordinates
                    ########################################################################
                    
                    # GEO coordinates of desired point
                    alt_p = zg[timer, lev, lat, lon] / 1e5 #cm to km
                    zgf[lat, lon]=alt_p #output 
                    lat_p = glat[lat]   #deg
                    lon_p = glon[lon]   #deg
                    maplat[lat]=glat[lat] #output 
                    maplon[lon]=glon[lon] #output 
                    timeg=gtime[timer] #minutes
                    #time
                    time_p = time_igrf + datetime.timedelta(minutes=timeg)               
                   
                    #Pressure levels
                    Z=glev[lev]
                    
                    pressuref=P0*np.exp(-Z) #pressure in millibars
                    pressuref_Pa=pressuref*100 #pressure in Pascals
                    Pressure_2D[lat,lon]=pressuref_Pa
                    
                    #Electric Potential (V)
                    Pot=Poten_all[timer, lev, lat, lon]
                    Potf[lat, lon]=Pot #output 
                    
                    ########################################################################
#                   Temperatures and densities
                    ########################################################################

                    #Temperatures
                    Tn=Tn_all[timer, lev, lat, lon]     #Kelvin
                    Te=Te_all[timer, lev, lat, lon]     #Kelvin
                    Ti=Ti_all[timer, lev, lat, lon]     #Kelvin
                    
                    Ti_Out[lat,lon]=Ti
                    Te_Out[lat,lon]=Te
                    Tn_Out[lat,lon]=Tn
                    
                    #mean molecular mass g/mol
                    barm=barm_all[timer, lev, lat, lon]

                    #Conversion factor (mmr->cm^(-3))
                    Nbarm=(P0*np.exp(-Z)*barm*1000)/(boltzmann*Tn)

                    #neutral Densities (cm^-3)
                    NO=nO_all_cm3[timer, lev, lat, lon] #cm^-3
                    NOf[lat, lon]=NO* (10 ** 6) #output m^-3
                    NO2=nO2_all_cm3[timer, lev, lat, lon] #cm^-3                 
                    NO2f[lat, lon]=NO2* (10 ** 6) #output m^-3
                    NN2=N2_all_cm3[timer, lev, lat, lon] #cm^-3
                    NN2f[lat, lon]=NN2* (10 ** 6) #output m^-3

                    # electron density
                    Ne = Ne_all[timer, lev, lat, lon] * (10 ** 6)  # m^-3
                    Nef[lat, lon]=Ne #output m^-3
                    Necm=Ne_all[timer, lev, lat, lon] # (cm^-3)

                    #ion Densities
                    NOp=NOp_all[timer, lev, lat, lon]  #cm^-3
                    NO2p=NO2p_all[timer, lev, lat, lon]  #cm^-3
                    NOpf[lat, lon]=NOp #output 
                    NO2pf[lat, lon]=NOp #output 
                    Nplus=Np_all[timer, lev, lat, lon]
                    NNOp=Necm-NOp+NO2p  #if O2+ density is available in the input file
                    NNOpf[lat, lon]=NNOp #output 
                    
                    rmass_n4s = 14
                    rmass_n2  = 28
                    
                    MO=mO/(NA*1000)  # Atomic oxygen mass in kg
                    MO2=(2*mO)/(NA*1000) # Molecular oxygen mass in kg
                    MNO=(mNO)/(NA*1000) #Nitric oxide mass in kg                    
                    MN2=rmass_n2/(NA*1000)   #Nitrogen mass in kg
                    MN=rmass_n4s/(NA*1000)
                    
                    
                    ########################################################################
#                   Velocities
                    ########################################################################

                    #neutral wind 
                    Une=Un_east[timer, lev, lat, lon]
                    Unn=Un_north[timer, lev, lat, lon]
                    Unu=Un_up[timer, lev, lat, lon]

                    Un_x = Une / 100  # m/s
                    Un_y = Unn / 100  # m/s
                    Un_z = Unu / 100  # m/s
                    Un = [Un_x, Un_y, Un_z] # neutral wind in ENU in m/s
                    
                    Unef[lat,lon]=Un_x #output (ENU)
                    Unnf[lat,lon]=Un_y #output (ENU)  
                    Unuf[lat,lon]=Un_z #output (ENU) 
                    
                    # ExB velocity from ENU to ECEF
                    Uie=Ui_east[timer, lev, lat, lon]
                    Uin=Ui_north[timer, lev, lat, lon]
                    Uiu=Ui_up[timer, lev, lat, lon]

                    Ui_x = Uie / 100  # m/sec
                    Ui_y = Uin / 100  # m/sec
                    Ui_z = Uiu / 100  # m/sec
                    Ui = [Ui_x, Ui_y, Ui_z]  # ExB in ENU in m/s
                    
                    #######################################################################
#                   Magnetic and Electric fields
                    #######################################################################
                    
                    # Magnetic Field from ENU to ECEF
                    pt = pyglow.Point(time_p, lat_p, lon_p, alt_p) # pyglow igrf
                    pt.run_igrf()
                    Be = pt.Bx
                    Bn = pt.By
                    Bu = pt.Bz
                    B = [Be, Bn, Bu]  # vector of magnetic field ENU in Telsa
                    Bxf[lat, lon]=Be #output (ENU)
                    Byf[lat, lon]=Bn #output (ENU)
                    Bzf[lat, lon]=Bu #output (ENU)
                    
                    Bx, By, Bz = enu_ecef(lat_p, lon_p, Be, Bn, Bu)  # Tesla in ECEF
                    B = [Bx, By, Bz]  # vector of magnetic field ECEF in Telsa

                    # Magnetic field unit vector
                    bnorm = np.sqrt(Bx * Bx + By * By + Bz * Bz)
                    b_unit = [Bx / bnorm, By / bnorm, Bz / bnorm]
                    bnorm = np.sqrt(Be * Be + Bn * Bn + Bu * Bu) #ENU
                    b_unit = [Be / bnorm, Bn / bnorm, Bu / bnorm] #ENU
                    B_enu= [Be, Bn, Bu]

                    #Electric Field perpendicular to the magnetic field
                    Evert=-np.cross(Ui,B_enu)  #V/m
                    Ee=Evert[0]
                    En=Evert[1]
                    Eu=Evert[2]
                    
                    enorm=np.sqrt(En*En+Eu*Eu+Ee*Ee)
                    e_unit=[Ee / enorm, En / enorm, Eu / enorm]
                    
                    
# #                     Evertx[lat, lon]=Ee #ENU
# #                     Everty[lat, lon]=En #ENU
# #                     Evertz[lat, lon]=Eu #ENU

                    #neutral wind perpendicular to the magnetic field
                    Unvert=np.cross(Un,b_unit)
                    Unvertx=Unvert[0]
                    Unverty=Unvert[1]
                    Unvertz=Unvert[2]
                    Unvertmag=np.sqrt(Unvert[0] * Unvert[0] + Unvert[1] * Unvert[1] + Unvert[2] * Unvert[2])
                    

#                     unvertxf[lat, lon]=Unvertx #output
#                     unvertyf[lat, lon]=Unverty #output
#                     unvertzf[lat, lon]=Unvertz #output
                    
#                     TIEGCM_Electric Fields
                    Ee_TIEGCM=EEX[timer, lev, lat, lon]*100
                    En_TIEGCM=EEY[timer, lev, lat, lon]*100
                    Eu_TIEGCM=EEZ[timer, lev, lat, lon]*100
                    ETIEGCM=[Ee_TIEGCM,En_TIEGCM,Eu_TIEGCM]
                

                    Ee_T, En_T, Eu_T = enu_ecef(lat_p, lon_p,Ee_TIEGCM,En_TIEGCM, Eu_TIEGCM)
                    Evert2=[Ee_T,En_T,Eu_T]

                    E_T_vert=np.cross(Evert2,b_unit)
                    Ee_T_vert=E_T_vert[0]
                    En_T_vert=E_T_vert[1]
                    Eu_T_vert=E_T_vert[2]
                                        
                    
                    #Perpendicular electric field in neutral atmosphere reference frame                                        
                    Estar=E_T_vert+np.cross(Unvert,B)
                                                           
                    Evertx[lat, lon]=Ee_TIEGCM #ENU
                    Everty[lat, lon]=En_TIEGCM  #ENU
                    Evertz[lat, lon]=Eu_TIEGCM  #ENU


                    #Calculate ExB velocities 
                    ExBcalc=np.cross(E_T_vert,b_unit)/(bnorm)
                    ExBx_calc[lat, lon]=ExBcalc[0]
                    ExBy_calc[lat, lon]=ExBcalc[1]
                    ExBz_calc[lat, lon]=ExBcalc[2]
                    
                    ########################################################################
#                   Gyrofrequencies and collision frequencies
                    ########################################################################

                    #gyrofrequencies (Hz)
                    bgauss=bnorm*10000
                    qeomeo10=1.7588028*10**7
                    qeoNa010=9.6489*10**3
                    rmassinv_op=1/mO
                    rmassinv_nop=1/mNO
                    rmassinv_o2p=1/mO2 
                    
                    omega_op=qeoNa010*bgauss*rmassinv_op
                    omega_o2p=qeoNa010*bgauss*rmassinv_o2p
                    omega_nop=qeoNa010*bgauss*rmassinv_nop
                    omega_op_inv=1/omega_op
                    omega_o2p_inv=1/omega_o2p
                    omega_nop_inv=1/omega_nop
                    omega_e=qeomeo10*bgauss
                    omega_e_inv=1/omega_e
                    
                    Omega_ef[lat, lon]=omega_e #output
                    Omega_Opf[lat, lon]=omega_op #output
                    Omega_O2pf[lat, lon]=omega_o2p #output
                    Omega_NOpf[lat, lon]=omega_nop #output
                    
                    #collision frequencies (Hz)
                    temps=(Ti+Tn)/2
                    rnu_o2p_o2=2.59 * (10**(-11))* np.sqrt(temps)*((1-0.073*np.log10(temps))**2)
                    rnu_op_o2=6.64 * (10**(-10))
                    rnu_nop_o2=4.27 * (10**(-10))
                    

                    
                    rnu_o2p_o=2.31*(10**(-10))
                    rnu_op_o=3.67 * (10**(-11)) * np.sqrt(temps)*((1-0.064*np.log10(temps))**2)*fcor
                    rnu_nop_o=2.44 * (10**(-10))
                    
                    rnu_o2p_n2=4.13*(10**(-10))
                    rnu_op_n2=6.82 * (10**(-10))
                    rnu_nop_n2=4.34*(10**(-10))
                    
                    rnu_o2p=(rnu_o2p_o2*NO2+rnu_o2p_o*NO+rnu_o2p_n2*NN2)*omega_o2p_inv
                    rnu_op=(rnu_op_o2*NO2+rnu_op_o*NO+rnu_op_n2*NN2)*omega_op_inv
                    rnu_nop=(rnu_nop_o2*NO2+rnu_nop_o*NO+rnu_nop_n2*NN2)*omega_nop_inv
                    
                    vOp=rnu_op_o2*NO2+rnu_op_o*NO+rnu_op_n2*NN2
                    vO2p=rnu_o2p_o2*NO2+rnu_o2p_o*NO+rnu_o2p_n2*NN2
                    vNOp=rnu_nop_o2*NO2+rnu_nop_o*NO+rnu_nop_n2*NN2
                    vin=vOp+vO2p+vNOp
                    
                    vop_o=rnu_op_o*NO
                    vop_o2=rnu_op_o2*NO2
                    vop_n2=rnu_op_n2*NN2
                    vo2p_o=rnu_o2p_o*NO
                    vo2p_o2=rnu_o2p_o2*NO2
                    vo2p_n2=rnu_o2p_n2*NN2
                    vnop_o=rnu_nop_o*NO
                    vnop_o2=rnu_nop_o2*NO2
                    vnop_n2=rnu_nop_n2*NN2
                    
                    ven=(2.33 * (10**(-11))*NN2*Te*(1-(1.21*(10**(-4)*Te))) \
                        + 1.82 * (10**(-10))*NO2*np.sqrt(Te)*(1+(3.6*(10**(-2)*np.sqrt(Te)))) \
                        +8.9 * (10**(-11))*NO*np.sqrt(Te)*(1+(5.7*(10**(-4)*Te))))
                    
                    rnu_ne=(2.33 * (10**(-11))*NN2*Te*(1-(1.21*(10**(-4)*Te))) \
                        + 1.82 * (10**(-10))*NO2*np.sqrt(Te)*(1+(3.6*(10**(-2)*np.sqrt(Te)))) \
                        +8.9 * (10**(-11))*NO*np.sqrt(Te)*(1+(5.7*(10**(-4)*Te))))*omega_e_inv
                    rnu_ne=4*rnu_ne
                    
                    vOpf[lat, lon]=vOp #Output file
                    venf[lat, lon]=ven #Output file
                    vO2pf[lat, lon]=vO2p #Output file
                    vNOpf[lat,lon]=vNOp 
                    vinf[lat, lon]=vin #Output file
                    
                    
                    
                    ##########################################################################
#                   Ion-electron (Coulomb) collision frequencies
                    ##########################################################################                    
                    ve_op=(54.5*NOp)/(Te**(1.5))
                    ve_o2p=(54.5*NO2p)/(Te**(1.5))
                    ve_nop=(54.5*NNOp)/(Te**(1.5))
                    ve_np=(54.5*Nplus)/(Te**(1.5))
                    ve_i=(ve_op+ve_o2p+ve_nop+ve_np)/4
                    # veif[lat,lon]=ve_i

                    ven=(2.33 * (10**(-11))*NN2*Te*(1-(1.21*(10**(-4)*Te))) \
                        + 1.82 * (10**(-10))*NO2*np.sqrt(Te)*(1+(3.6*(10**(-2)*np.sqrt(Te)))) \
                        +8.9 * (10**(-11))*NO*np.sqrt(Te)*(1+(5.7*(10**(-4)*Te))))
                    
                    ve_n2=2.33 * (10**(-11))*NN2*Te*(1-(1.21*(10**(-4)*Te)))
                    ve_o=8.9 * (10**(-11))*NO*np.sqrt(Te)*(1+(5.7*(10**(-4)*Te)))
                    ve_o2=1.82 * (10**(-10))*NO2*np.sqrt(Te)*(1+(3.6*(10**(-2)*np.sqrt(Te))))
#                     ve_he=4.6* (10**(-10))*he_cm3*np.sqrt(Te)
                    

#                     ########################################################################
# #                   Conductivities
#                     ########################################################################
    
                    qe_fac=(electron*10**10)/bgauss
                    Necm2=NOp+NO2p+NNOp
                    sigmaPed=qe_fac*((NOp*rnu_op/(1+rnu_op**2))+(NO2p*rnu_o2p/(1+rnu_o2p**2)) \
                                    +(NNOp*rnu_nop/(1+rnu_nop**2))+Necm2*rnu_ne/(1+rnu_ne**2))
                    
                    sigmaHall=qe_fac*(Necm2/(1+rnu_ne**2)-NOp/(1+rnu_op**2)-NO2p/(1+rnu_o2p**2)-NNOp/(1+rnu_nop**2))
                    
                    sigmaPedf[lat, lon]=sigmaPed*10**(5) #output 10^-5 Si/m
                    sigmaHallf[lat, lon]=sigmaHall*10**(5) #output 10^-5 Si/m

                    #Parallel conductivity
                    sigma0=(Ne*electron*electron)/(me*ven) #output 10^-5 Si/m
                    sigma_par[lat, lon]=sigma0*10**(5)
                    
                    
# 
                    ########################################################################
#                   Velocities
                    ########################################################################

                    #Ion Velocity in neutral reference frame (formula derived through ion momentum equation)
                    #O+
                    vi_op_star=(vOp*omega_op*Estar+omega_op**2*(np.cross(Estar,b_unit)))/(bnorm*(vOp**2+omega_op**2))
                    vi_op_starx=vi_op_star[0] #m/s
                    vi_op_stary=vi_op_star[1] #m/s
                    vi_op_starz=vi_op_star[2] #m/s
                    vi_op_starmag=np.sqrt(vi_op_star[0] * vi_op_star[0] + vi_op_star[1] * vi_op_star[1] + vi_op_star[2] * vi_op_star[2])

                    vie_op=vi_op_starx+Unvertx #from neutral frame to ENU
                    vin_op=vi_op_stary+Unverty #from neutral frame to ENU
                    viu_op=vi_op_starz+Unvertz #from neutral frame to ENU

                                       
                    vinorm_op=np.sqrt(vie_op*vie_op+vin_op*vin_op+viu_op*viu_op)
                    e_unit_op=[vie_op / vinorm_op, vin_op / vinorm_op, viu_op / vinorm_op]
                    
                    print(Estar,vi_op_star,vinorm_op)
                    
#                     vi_mag_op[lat, lon]=vinorm_op
#                     vi_starxf_op[lat, lon]=vie_op #output
#                     vi_staryf_op[lat, lon]=vin_op #output
#                     vi_starzf_op[lat, lon]=viu_op #output
                    
#                     #O2+
#                     vi_o2p_star=(vO2p*omega_o2p*Estar+omega_o2p**2*(np.cross(Estar,b_unit)))/(bnorm*(vO2p**2+omega_o2p**2))
#                     vi_o2p_starx=vi_o2p_star[0] #m/s
#                     vi_o2p_stary=vi_o2p_star[1] #m/s
#                     vi_o2p_starz=vi_o2p_star[2] #m/s
#                     vi_o2p_starmag=np.sqrt(vi_o2p_star[0] * vi_o2p_star[0] + vi_o2p_star[1] * vi_o2p_star[1] + vi_o2p_star[2] * vi_o2p_star[2])

#                     vie_o2p=vi_o2p_starx+Unvertx #from neutral frame to ENU
#                     vin_o2p=vi_o2p_stary+Unverty #from neutral frame to ENU
#                     viu_o2p=vi_o2p_starz+Unvertz #from neutral frame to ENU

                                       
#                     vinorm_o2p=np.sqrt(vie_o2p*vie_o2p+vin_o2p*vin_o2p+viu_o2p*viu_o2p)
#                     e_unit_o2p=[vie_o2p / vinorm_o2p, vin_o2p / vinorm_o2p, viu_o2p / vinorm_o2p]
                    
#                     vi_mag_o2p[lat, lon]=vinorm_o2p
#                     vi_starxf_o2p[lat, lon]=vie_o2p #output
#                     vi_staryf_o2p[lat, lon]=vin_o2p #output
#                     vi_starzf_o2p[lat, lon]=viu_o2p #output
                    
#                     #NO+
#                     vi_nop_star=(vNOp*omega_nop*Estar+omega_nop**2*(np.cross(Estar,b_unit)))/(bnorm*(vNOp**2+omega_nop**2))
#                     vi_nop_starx=vi_nop_star[0] #m/s
#                     vi_nop_stary=vi_nop_star[1] #m/s
#                     vi_nop_starz=vi_nop_star[2] #m/s
#                     vi_nop_starmag=np.sqrt(vi_nop_star[0] * vi_nop_star[0] + vi_nop_star[1] * vi_nop_star[1] + vi_nop_star[2] * vi_nop_star[2])

#                     vie_nop=vi_nop_starx+Unvertx #from neutral frame to ENU
#                     vin_nop=vi_nop_stary+Unverty #from neutral frame to ENU
#                     viu_nop=vi_nop_starz+Unvertz #from neutral frame to ENU

                                       
#                     vinorm_nop=np.sqrt(vie_nop*vie_nop+vin_nop*vin_nop+viu_nop*viu_nop)
#                     e_unit_nop=[vie_nop / vinorm_nop, vin_nop / vinorm_nop, viu_nop / vinorm_nop]
                    
#                     vi_mag_nop[lat, lon]=vinorm_nop
#                     vi_starxf_nop[lat, lon]=vie_nop #output
#                     vi_staryf_nop[lat, lon]=vin_nop #output
#                     vi_starzf_nop[lat, lon]=viu_nop #output
                    
#                     #Electron Velocity in neutral reference frame (formula derived through electron momentum equation)
#                     ve_star=(-ven*omega_e*Estar+omega_e**2*(np.cross(Estar,b_unit)))/(bnorm*(ven**2+omega_e**2))
#                     ve_starx=ve_star[0] #m/s
#                     ve_stary=ve_star[1] #m/s
#                     ve_starz=ve_star[2] #m/s
#                     ve_starmag=np.sqrt(ve_star[0] * ve_star[0] + ve_star[1] * ve_star[1] + ve_star[2] * ve_star[2])

#                     ve_xtemp=ve_starx+Unvertx #from neutral frame to ENU
#                     ve_ytemp=ve_stary+Unverty #from neutral frame to ENU
#                     ve_ztemp=ve_starz+Unvertz #from neutral frame to ENU
                  
#                     vee_out[lat, lon]=ve_xtemp
#                     ven_out[lat, lon]=ve_ytemp
#                     veu_out[lat, lon]=ve_ztemp    
                    
#                     ########################################################################
# #                     Magnetic parameters
#                     ########################################################################
    
#                     dipmag=np.arctan(Bz/np.sqrt(By**2+Bx**2))
#                     sndip=np.sin(dipmag)
#                     decmag=np.arctan2(By,Bx)
#                     sndec=np.sin(decmag)
#                     sn2dec=sndec**2
#                     csdec=np.cos(decmag)
#                     tm1=sn2dec+(1-sn2dec)*sndip**2
#                     tm2=(1-sn2dec)+sn2dec*sndip**2
#                     tm3=sndec*csdec*(1-sndip**2)
                    
#                     ############################rnu##############################################
# #                   Ohmic Heating 
#                     ########################################################################## 
                                        
#                     A=E_T_vert+np.cross(Unvert,B)
# #                     L=np.sqrt(A[0] * A[0] + A[1] * A[1] + A[2] * A[2])

#                     Ohmic2=sigmaPed*np.dot(A,A)
# #                     Ohmic2=sigmaPed*L*L
#                     Ohmic[lat, lon]=Ohmic2*1000 #mW/m^3
    
#                     ##########################################################################
# #                     Joule Heating - Frictional Heating
#                     ##########################################################################
    
#                     Joule_op=electron*NOp*(10**6)*np.dot(vi_op_star,A)
#                     Joule_o2p=electron*NO2p*(10**6)*np.dot(vi_o2p_star,A)
#                     Joule_nop=electron*NNOp*(10**6)*np.dot(vi_nop_star,A)
#                     Joule1=Joule_op+Joule_o2p+Joule_nop
#                     Joule[lat, lon]=Joule1*1000 #mW/m^3
                    
#                     Frictional_op=MO*NOp*(10**6)*vOp*vi_op_starmag*vi_op_starmag
#                     Frictional_o2p=MO2*NO2p*(10**6)*vO2p*vi_o2p_starmag*vi_o2p_starmag
#                     Frictional_nop=MNO*NNOp*(10**6)*vNOp*vi_nop_starmag*vi_nop_starmag
#                     Frictional1=Frictional_op+Frictional_o2p+Frictional_nop
#                     Frictional[lat, lon]=Frictional1*1000 #mW/m^3
                    
#                     rho=den_all[timer, lev, lat, lon]*1000
#                     JH_rho[lat, lon]=(Ohmic2/rho)*1000 #mW/kg
                    
#                     ##########################################################################
# #                   Convection Heating - Wind Correction
#                     ##########################################################################
                                        
#                     UNxB=np.cross(Unvert,B)
#                     UNxBmag=np.sqrt(UNxB[0] * UNxB[0] + UNxB[1] * UNxB[1] + UNxB[2] * UNxB[2])
#                     ExB=np.cross(E_T_vert,B)


#                     Convenction_heating=sigmaPed*np.dot(E_T_vert,E_T_vert)
#                     Convenction_heating_Out[lat, lon]=Convenction_heating*1000 #mW/m^3
                    
# #                     Wind_heating=sigmaPed*UNxBmag*UNxBmag-2*sigmaPed*np.dot(Un,ExB)
#                     Wind_heating=(sigmaPed*bnorm**2*(tm2*Un_x**2+tm1*Un_y**2-2*tm3*Un_x*Un_y
#                                                       -2*(Un_x*Ui_x+Un_y*Ui_y)))
#                     Wind_heating_Out[lat, lon]=Wind_heating*1000 #mW/m^3
        
#                     #TIEGCM QWIND and QAMIE
# #                     QAMIE1=QAMIE[timer, lev, lat, lon]
# #                     QAMIE_T[lat,lon]=QAMIE1
                    
# #                     print(Convenction_heating,QAMIE1)
# #                     QWIND1=QWIND[timer, lev, lat, lon]
# #                     QWIND_T[lat,lon]=QWIND1                               
                    
#                     Ohmic_heating_OhmsLaw=Convenction_heating+Wind_heating
#                     Ohmic_heating_OhmsLaw_Out[lat, lon]=Ohmic_heating_OhmsLaw*1000 #mW/m^3
                    
#                     ##########################################################################
# #                   Ohmic per Pressure/ Pressure per Ohmic
#                     ##########################################################################
                                   
#                     Ohmic_pressure=(Ohmic2/pressuref_Pa)
#                     Ohmic_Press[lat,lon]=Ohmic_pressure
                
#                     pressure_ohmic_tmp=(1/Ohmic_pressure)
#                     Press_Ohmic[lat,lon]=pressure_ohmic_tmp
                    
#                     ##########################################################################
# #                   Electric Currents
#                     ##########################################################################
                    
#                     #perpendicular electric current density (A/m^2) (Ohm's LaW)
#                     J_p_Ohmic=sigmaPed*Estar+sigmaHall*np.cross(b_unit,Estar)
#                     J_p_Ohmicx=J_p_Ohmic[0]
#                     J_p_Ohmicy=J_p_Ohmic[1]
#                     J_p_Ohmicz=J_p_Ohmic[2]
                    
#                     #Pedersen and Hall currents
#                     J_Pedersen=sigmaPed*Estar
#                     J_Hall=sigmaHall*np.cross(b_unit,Estar)
                    
#                     Jpe=J_Pedersen[0]
#                     Jpn=J_Pedersen[1]
#                     Jpu=J_Pedersen[2]
#                     Jhe=J_Hall[0]
#                     Jhn=J_Hall[1]
#                     Jhu=J_Hall[2]

                    
#                     #####################
#                     Jpnorm=np.sqrt(Jpn*Jpn+Jpu*Jpu+Jpe*Jpe)
#                     Jp_unit=[Jpe / Jpnorm, Jpn / Jpnorm, Jpu / Jpnorm]
                    
#                     Jhnorm=np.sqrt(Jhn*Jhn+Jhu*Jhu+Jhe*Jhe)
#                     Jh_unit=[Jhe / Jhnorm, Jhn / Jhnorm, Jhu / Jhnorm]
                    
#                     J_Pede[lat,lon]=Jpe #output 
#                     J_Pedn[lat,lon]=Jpn #output  
#                     J_Pedu[lat,lon]=Jpu #output 
#                     J_Halle[lat,lon]=Jhe #output 
#                     J_Halln[lat,lon]=Jhn #output 
#                     J_Hallu[lat,lon]=Jhu #output 
#                     J_Ohme[lat, lon]=Jpe+Jhe #output 
#                     J_Ohmn[lat, lon]=Jpn+Jhn #output 
#                     J_Ohmu[lat, lon]=Jpu+Jhu #output 
                    
#                     J_mag[lat,lon]=np.sqrt((Jpe+Jhe)**2+(Jpn+Jhn)**2+(Jpu+Jhu)**2) #output 

#                     #perpendicular electric current density (A/m^2) (densities)
#                     J_den=electron*Ne*(vi_op_star-ve_star)
#                     J_denx=J_den[0]
#                     J_deny=J_den[1]
#                     J_denz=J_den[2]
                    
#                     ##########################################################################
# #                   JxB forcing
#                     ##########################################################################

#                     JxB=np.cross(J_p_Ohmic,B)
#                     JxBe[lat, lon]=JxB[0]
#                     JxBn[lat, lon]=JxB[1]
#                     JxBu[lat, lon]=JxB[2]
                    
#                     ##########################################################################
# #                   Mechanical Power and Energy
#                     ##########################################################################
                    
#                     Mechanical_power=np.dot(Un,JxB)
#                     Mechanical_power_Out[lat, lon]=Mechanical_power
#                     Energy=Ohmic_heating_OhmsLaw+Mechanical_power
#                     Energy_Out[lat, lon]=Energy
                    
#                     ##########################################################################
# #                   Cross Sections
#                     ##########################################################################
#                     N_neutral=(NO2+NN2+NO)*10**6
#                     MN2=(mN2)/(NA*1000)
#                     M_ion=MO+MO2+MNO
                    
#                     cross=(vin/N_neutral)/(np.sqrt((2*boltzmann*Ti)/M_ion))
#                     cross_section[lat,lon]=cross
                    
#                     cross_op=(vOp/N_neutral)/(np.sqrt((2*boltzmann*Ti)/MO))
#                     cross_section_op[lat,lon]=cross_op
                    
#                     cross_o2p=(vO2p/N_neutral)/(np.sqrt((2*boltzmann*Ti)/MO2))
#                     cross_section_o2p[lat,lon]=cross_o2p
                    
#                     cross_nop=(vNOp/N_neutral)/(np.sqrt((2*boltzmann*Ti)/MNO))
#                     cross_section_nop[lat,lon]=cross_nop
                    
#                     warnings.simplefilter('ignore')
                    
#                     #print(Ohmic2*1000,Ohmic_heating_OhmsLaw*1000,Convenction_heating*1000,Wind_heating*1000 )
                    
                    
#                     ##########################################################################
# #                     Ion heating rates
#                     ##########################################################################
    
#                     qDTop_o=3*NOp*(10 ** 6)*boltzmann_si*vop_o*(MO/(MO+MO))*(Ti-Tn)
#                     qDTop_o2=3*NOp*(10 ** 6)*boltzmann_si*vop_o2*(MO/(MO2+MO))*(Ti-Tn)
#                     qDTop_n2=3*NOp*(10 ** 6)*boltzmann_si*vop_n2*(MO/(MN2+MO))*(Ti-Tn)
#                     qDTo2p_o=3*NO2p*(10 ** 6)*boltzmann_si*vo2p_o*(MO2/(MO+MO2))*(Ti-Tn)
#                     qDTo2p_o2=3*NO2p*(10 ** 6)*boltzmann_si*vo2p_o2*(MO2/(MO2+MO2))*(Ti-Tn)
#                     qDTo2p_n2=3*NO2p*(10 ** 6)*boltzmann_si*vo2p_n2*(MO2/(MN2+MO2))*(Ti-Tn)
#                     qDTnop_o=3*NNOp*(10 ** 6)*boltzmann_si*vnop_o*(MNO/(MO+MNO))*(Ti-Tn)
#                     qDTnop_o2=3*NNOp*(10 ** 6)*boltzmann_si*vnop_o2*(MNO/(MO2+MNO))*(Ti-Tn)
#                     qDTnop_n2=3*NNOp*(10 ** 6)*boltzmann_si*vnop_n2*(MNO/(MN2+MNO))*(Ti-Tn)
                    
#                     qDTop_n=qDTop_o+qDTop_o2+qDTop_n2
#                     qDTo2p_n=qDTo2p_o+qDTo2p_o2+qDTo2p_n2
#                     qDTnop_n=qDTnop_o+qDTnop_o2+qDTnop_n2
                    
#                     qDTi_n=qDTop_n+qDTo2p_n+qDTnop_n
                    
#                     qDTop_of[lat,lon]=qDTop_o
#                     qDTop_o2f[lat,lon]=qDTop_o2
#                     qDTop_n2f[lat,lon]=qDTop_n2
#                     qDTo2p_of[lat,lon]=qDTo2p_o
#                     qDTo2p_o2f[lat,lon]=qDTo2p_o2
#                     qDTo2p_n2f[lat,lon]=qDTo2p_n2
#                     qDTnop_of[lat,lon]=qDTnop_o
#                     qDTnop_o2f[lat,lon]=qDTnop_o2
#                     qDTnop_n2f[lat,lon]=qDTnop_n2
                    
#                     qDTop_nf[lat,lon]=qDTop_n
#                     qDTo2p_nf[lat,lon]=qDTo2p_n
#                     qDTnop_nf[lat,lon]=qDTnop_n
                    
#                     qDTi_nf[lat,lon]=qDTi_n*1000 #mW/m^3
                    
#                     ##########################################################################
# #                     Cooling rates
#                     ##########################################################################
                    
#                     #N2 rotation
#                     Le_N2_rotf=((3.5*10**(-14)*Necm*NN2*(Te-Tn))/np.sqrt(Te))*1.60217662*10**(-16)
#                     Le_N2_rot_2d[lat,lon]=Le_N2_rotf
#                     #O2 rotation
#                     Le_O2_rotf=((5.2*10**(-15)*Necm*NO2*(Te-Tn))/np.sqrt(Te))*1.60217662*10**(-16)
#                     Le_O2_rot_2d[lat,lon]=Le_O2_rotf
#                     #O2 vibration
#                     logQ_Te=-19.9171+0.0267*Te-3.9960*(10**(-5))*(Te**2) \
#                             +3.5187*(10**(-8))*(Te**3)-1.9228*(10**(-11))*(Te**4) \
#                             +6.6865*(10**(-15))*(Te**5)-1.4791*(10**(-18))*(Te**6) \
#                             +2.0127*(10**(-22))*(Te**7)-1.5346*(10**(-26))*(Te**8) \
#                             +5.0148*(10**(-31))*(Te**9)

#                     Q_Te=10**(logQ_Te)


#                     Le_O2_vibf=(Necm*NO2*Q_Te*(1-np.exp(2239*(Te**(-1)-Tn**(-1)))))*1.60217662*10**(-16) 
#                     Le_O2_vib_2d[lat,lon]=Le_O2_vibf
                    
#                     #O fine structure
#                     D=5+np.exp(-326.6/Tn)+3*np.exp(-227.7/Tn)
#                     S21=1.863*10**(-11)
#                     S20=1.191*10**(-11)
#                     S10=8.249*10**(-16)*Te**(0.6)*np.exp(-227.7/Tn)
                    
#                     Le_O_finef=(((Necm*NO)/D)*((S10*(1-np.exp(98.9*(1/Te-1/Tn)))) \
#                                                +S20*(1-np.exp(326.6*(1/Te-1/Tn))) \
#                                                +S21*(1-np.exp(227.7*(1/Te-1/Tn)))))*1.60217662*10**(-16) 
                    
#                     Le_O_fine_2d[lat,lon]=Le_O_finef
                    
#                     #N2 vibration
#                     E1=3353 #K
#                     Tvib=Tn

#                     A01=2.025
#                     A02=-7.066
#                     A03=-8.211
#                     A04=-9.713
#                     A05=-10.353
#                     A06=-10.819
#                     A07=-10.183
#                     A08=-12.698
#                     A09=-14.710
#                     A010=-17.538
#                     B01=8.782*10**(-4)
#                     B02=1.0001*10**(-2)
#                     B03=1.092*10**(-2)
#                     B04=1.204*10**(-2)
#                     B05=1.243*10**(-2)
#                     B06=1.244*10**(-2)
#                     B07=1.185*10**(-2)
#                     B08=1.309*10**(-2)
#                     B09=1.409*10**(-2)
#                     B010=1.6*10**(-2)
#                     C01=2.954*10**(-7)
#                     C02=-3.066*10**(-6)
#                     C03=-3.369*10**(-6)
#                     C04=-3.732*10**(-6)
#                     C05=-3.850*10**(-6)
#                     C06=-3.771*10**(-6)
#                     C07=-3.570*10**(-6)
#                     C08=-3.952*10**(-6)
#                     C09=-4.249*10**(-6)
#                     C010=-4.916*10**(-6)
#                     D01=-9.562*10**(-11)
#                     D02=4.436*10**(-10)
#                     D03=4.891*10**(-10)
#                     D04=5.431*10**(-10)
#                     D05=5.600*10**(-10)
#                     D06=5.385*10**(-10)
#                     D07=5.086*10**(-10)
#                     D08=5.636*10**(-10)
#                     D09=6.058*10**(-10)
#                     D010=7.128*10**(-10)
#                     F01=7.252*10**(-15)
#                     F02=-2.449*10**(-14)
#                     F03=-2.706*10**(-14)
#                     F04=-3.008*10**(-14)
#                     F05=-3.100*10**(-14)
#                     F06=-2.936*10**(-14)
#                     F07=-2.769*10**(-14)
#                     F08=-3.071*10**(-14)
#                     F09=-3.3*10**(-14)
#                     F010=-3.941*10**(-14)

#                     A12=-3.413
#                     A13=-4.160
#                     A14=-5.193
#                     A15=-5.939
#                     A16=-8.261
#                     A17=-8.185
#                     A18=-10.823
#                     A19=-11.273
#                     B12=7.326*10**(-3)
#                     B13=7.803*10**(-3)
#                     B14=8.360*10**(-3)
#                     B15=8.807*10**(-3)
#                     B16=1.01*10**(-2)
#                     B17=1.01*10**(-2)
#                     B18=1.199*10**(-2)
#                     B19=1.283*10**(-2)
#                     C12=-2.2*10**(-6)
#                     C13=-2.352*10**(-6)
#                     C14=-2.526*10**(-6)
#                     C15=-2.669*10**(-6)
#                     C16=-3.039*10**(-6)
#                     C17=-3.039*10**(-6)
#                     C18=-3.62*10**(-6)
#                     C19=-3.879*10**(-6)
#                     D12=3.128*10**(-10)
#                     D13=3.352*10**(-10)
#                     D14=3.606*10**(-10)
#                     D15=3.806*10**(-10)
#                     D16=4.318*10**(-10)
#                     D17=4.318*10**(-10)
#                     D18=5.159*10**(-10)
#                     D19=5.534*10**(-10)
#                     F12=-1.702*10**(-14)
#                     F13=-1.828*10**(-14)
#                     F14=-1.968*10**(-14)
#                     F15=-2.073*10**(-14)
#                     F16=-2.347*10**(-14)
#                     F17=-2.347*10**(-14)
#                     F18=-2.810*10**(-14)
#                     F19=-3.016*10**(-14)


#                     logQ01=A01+B01*Te+C01*Te**2+D01*Te**3+F01*Te**4-16
#                     logQ02=A02+B02*Te+C02*Te**2+D02*Te**3+F02*Te**4-16
#                     logQ03=A03+B03*Te+C03*Te**2+D03*Te**3+F03*Te**4-16
#                     logQ04=A04+B04*Te+C04*Te**2+D04*Te**3+F04*Te**4-16
#                     logQ05=A05+B05*Te+C05*Te**2+D05*Te**3+F05*Te**4-16
#                     logQ06=A06+B06*Te+C06*Te**2+D06*Te**3+F06*Te**4-16
#                     logQ07=A07+B07*Te+C07*Te**2+D07*Te**3+F07*Te**4-16
#                     logQ08=A08+B08*Te+C08*Te**2+D08*Te**3+F08*Te**4-16
#                     logQ09=A09+B09*Te+C09*Te**2+D09*Te**3+F09*Te**4-16
#                     logQ010=A010+B010*Te+C010*Te**2+D010*Te**3+F010*Te**4-16

#                     logQ12=A12+B12*Te+C12*Te**2+D12*Te**3+F12*Te**4-16
#                     logQ13=A13+B13*Te+C13*Te**2+D13*Te**3+F13*Te**4-16
#                     logQ14=A14+B14*Te+C14*Te**2+D14*Te**3+F14*Te**4-16
#                     logQ15=A15+B15*Te+C15*Te**2+D15*Te**3+F15*Te**4-16
#                     logQ16=A16+B16*Te+C16*Te**2+D16*Te**3+F16*Te**4-16
#                     logQ17=A17+B17*Te+C17*Te**2+D17*Te**3+F17*Te**4-16
#                     logQ18=A18+B18*Te+C18*Te**2+D18*Te**3+F18*Te**4-16
#                     logQ19=A19+B19*Te+C19*Te**2+D19*Te**3+F19*Te**4-16

#                     Le_N2_vibf=(10**(-12)*Necm*NN2*(1-np.exp(-E1/Tvib)) \
#                             *((10**(logQ01)*(1-np.exp(1*E1*(Te**(-1)-Tvib**(-1))))) \
#                             +(10**(logQ02)*(1-np.exp(2*E1*(Te**(-1)-Tvib**(-1)))))  \
#                             +(10**(logQ03)*(1-np.exp(3*E1*(Te**(-1)-Tvib**(-1)))))  \
#                             +(10**(logQ04)*(1-np.exp(4*E1*(Te**(-1)-Tvib**(-1)))))   \
#                             +(10**(logQ05)*(1-np.exp(5*E1*(Te**(-1)-Tvib**(-1)))))   \
#                             +(10**(logQ06)*(1-np.exp(6*E1*(Te**(-1)-Tvib**(-1)))))   \
#                             +(10**(logQ07)*(1-np.exp(7*E1*(Te**(-1)-Tvib**(-1)))))   \
#                             +(10**(logQ08)*(1-np.exp(8*E1*(Te**(-1)-Tvib**(-1)))))   \
#                             +(10**(logQ09)*(1-np.exp(9*E1*(Te**(-1)-Tvib**(-1)))))   \
#                             +(10**(logQ010)*(1-np.exp(10*E1*(Te**(-1)-Tvib**(-1)))))    \
#                              )  \
#                              +10**(-12)*Necm*NN2*(1-np.exp(-E1/Tvib))*np.exp(-E1/Tvib)  \
#                              *((10**(logQ12)*(1-np.exp(1*E1*(Te**(-1)-Tvib**(-1)))))  \
#                             +(10**(logQ13)*(1-np.exp(2*E1*(Te**(-1)-Tvib**(-1)))))  \
#                             +(10**(logQ14)*(1-np.exp(3*E1*(Te**(-1)-Tvib**(-1)))))   \
#                             +(10**(logQ15)*(1-np.exp(4*E1*(Te**(-1)-Tvib**(-1)))))   \
#                             +(10**(logQ16)*(1-np.exp(5*E1*(Te**(-1)-Tvib**(-1)))))   \
#                             +(10**(logQ17)*(1-np.exp(6*E1*(Te**(-1)-Tvib**(-1)))))   \
#                             +(10**(logQ18)*(1-np.exp(7*E1*(Te**(-1)-Tvib**(-1)))))   \
#                             +(10**(logQ19)*(1-np.exp(8*E1*(Te**(-1)-Tvib**(-1)))))   \
#                             ))*1.60217662*10**(-16)  
                    
#                     Le_N2_vib_2d[lat,lon]=Le_N2_vibf



#                     #O(1D) excitation
#                     d_i=2.4*10**4+0.3*(Te-1500)-1.947*(10**(-5))*(Te-1500)*(Te-4000)
                    
#                     Le_O_1Df=(1.57*10**(-12)*Necm*NO*np.exp(d_i*((Te-3000)/(3000*Te))) \
#                               *(np.exp(-22713*((Te-Tn)/(Te*Tn)))-1))*1.60217662*10**(-16)
                    
#                     Le_O_1D_2d[lat,lon]=Le_O_1Df
                    
#                     #electron cooling rates sum
#                     Lef=Le_N2_rotf+Le_N2_vibf+Le_O2_vibf+Le_O_finef+Le_O_1Df+Le_O2_rotf
#                     # LeOp=
                   
#                     Le_all_2d[lat,lon]=Lef
#                     # print(Le_N2_rotf,Le_N2_rotf,Le_O2_vibf,Le_O_finef,Le_O_1Df,Lef)
                    
#                     #Electron neutral elastic collisions
#                     qDTe_of=3*Necm*(10 ** 6)*boltzmann_si*ve_o*(me/(me+MO))*(Te-Tn)
#                     qDTe_o2f=3*Necm*(10 ** 6)*boltzmann_si*ve_o2*(me/(me+MO2))*(Te-Tn)
#                     qDTe_n2f=3*Necm*(10 ** 6)*boltzmann_si*ve_n2*(me/(me+MN2))*(Te-Tn)
# #                     qDTe_hef=3*Necm*(10 ** 6)*boltzmann_si*ve_he*(me/(me+MHE))*(Te-Tn)
                    
#                     qDTe_n_elastic=qDTe_of+qDTe_o2f+qDTe_n2f #+qDTe_hef
                    
#                     qDTe_o_2d[lat,lon]=qDTe_of
#                     qDTe_o2_2d[lat,lon]=qDTe_o2f
#                     qDTe_n2_2d[lat,lon]=qDTe_n2f
# #                     qDTe_he[lat,lon]=qDTe_hef
#                     qDTe_n_2d[lat,lon]=qDTe_n_elastic

#                     #electron-ion coulomp collisions
#                     qDTe_opf=3*Necm*(10 ** 6)*boltzmann_si*ve_op*(me/(me+MO))*(Te-Ti)
#                     qDTe_o2pf=3*Necm*(10 ** 6)*boltzmann_si*ve_o2p*(me/(me+MO2))*(Te-Ti)
#                     qDTe_nopf=3*Necm*(10 ** 6)*boltzmann_si*ve_nop*(me/(me+MNO))*(Te-Ti)
#                     qDTe_npf=3*Necm*(10 ** 6)*boltzmann_si*ve_np*(me/(me+MN))*(Te-Ti)
#                     qDTe_if=qDTe_opf+qDTe_o2pf+qDTe_nopf+qDTe_npf
                    
#                     qDTe_op_2d[lat,lon]=qDTe_opf
#                     qDTe_o2p_2d[lat,lon]=qDTe_o2pf
#                     qDTe_nop_2d[lat,lon]=qDTe_nopf
#                     qDTe_np_2d[lat,lon]=qDTe_npf
#                     qDTe_i_2d[lat,lon]=qDTe_if

                    
    print("Calculation executed!")
    print("Total run time: %s seconds" % (time.time() - start_time))
tiegcm_file='../data/tiegcm2.0_res2.5_sech_St_Patrick_Weimer_031.nc'    
timer_value=22
pressure_level=12
    
run_map(tiegcm_file,timer_value,pressure_level)
# Out:
# [-356.51597759 -131.1710736    24.46039075] 374.7999982714089
# [-354.1613526  -129.19947693   29.4604034 ] 371.4891116144936
# [-351.84481061 -127.20232583   34.33889202] 368.2788877120708
# [-349.5683432  -125.18920195   39.08567162] 365.1727202329849
# [-347.34894612 -123.15940552   43.69651097] 362.18371075511294
# [-345.18604975 -121.12341766   48.16203071] 359.31225879187485
# [-343.0926705  -119.08339714   52.47815653] 356.5680821939086
# [-341.07340622 -117.04651867   56.63874687] 353.95446058792595
# [-339.13224856 -115.01944279   60.63831045] 351.47355525780614
# [-337.27958381 -113.00676813   64.47395672] 349.132653676078
# [-335.51358198 -111.01699201   68.1398297 ] 346.9284599867724
# [-333.84452461 -109.05492591   71.63435771] 344.8678449115244
# [-332.27295379 -107.12794267   74.95373904] 342.9490333662767
# [-330.80061681 -105.24299798   78.09513142] 341.1711238620721
# [-329.43480258 -103.40610466   81.0579494 ] 339.53825386825554
# [-328.17131315 -101.6246395    83.83883302] 338.0437756208551
# [-326.7337777   -99.84937609   86.36055409] 336.39579859152855
# [-324.08229347  -97.89230335   88.32359736] 333.5038298025441
# [-321.54274819  -96.03070732   90.08361528] 330.7499092412382
# [-319.11652304  -94.27043222   91.64442221] 328.1333585049446
# [-316.80796916  -92.61730007   93.01127354] 325.6567760860202
# [-314.61586169  -91.07619959   94.18826051] 323.31731306552496
# [-312.53911038  -89.6514272    95.17991453] 321.1124300085446
# [-310.57991303  -88.34779002   95.99212671] 319.04340599483794
# [-308.73578864  -87.16840893   96.62965798] 317.10673858029827
# [-307.01000354  -86.11810678   97.09931489] 315.3055693641565
# [-305.39879008  -85.19882067   97.40587825] 313.63553616957904
# [-303.90114401  -84.41296195   97.55510581] 312.0955595518969
# [-302.51445217  -83.76172358   97.55227135] 310.6829563643408
# [-301.24233035  -83.24972828   97.4048349 ] 309.40267654945416
# [-300.07779025  -82.87466463   97.1165117 ] 308.2472935284659
# [-299.02547656  -82.64185353   96.69513053] 307.223674181363
# [-298.07550074  -82.54505301   96.14291644] 306.32090177202105
# [-297.23231442  -82.58917619   95.46738293] 305.5461031592428
# [-296.49542398  -82.77519512   94.67403353] 304.90051195160083
# [-295.86036852  -83.09974906   93.7664129 ] 304.38027543986317
# [-295.32471895  -83.56064502   92.748507  ] 303.98412422619236
# [-294.88831587  -84.15819392   91.6250558 ] 303.71402101891545
# [-294.55265677  -84.89445419   90.40130469] 303.574300410029
# [-294.30996682  -85.7593353    89.07747017] 303.5562916409271
# [-294.16412151  -86.75739723   87.65921757] 303.66773327261626
# [-294.11269716  -87.88672679   86.14906365] 303.9081195385131
# [-294.15184779  -89.13804051   84.54716236] 304.2731364487414
# [-294.28282531  -90.5140951    82.85716869] 304.767563292932
# [-294.50567783  -92.01695319   81.08206887] 305.3948536652814
# [-294.81420929  -93.62969224   79.21842266] 306.1458073223678
# [-295.2106635   -95.35755448   77.26970441] 307.02712495260204
# [-295.69351636  -97.19868975   75.2365734 ] 308.03940785735256
# [-296.26072591  -99.14813684   73.11845193] 309.18165135348136
# [-296.74747213 -101.17994405   70.88501259] 310.28900956943266
# [-297.20777794 -103.2924062    68.5490081 ] 311.416652639704
# [-297.74544501 -105.4965677    66.13032912] 312.6711597710023
# [-298.35896426 -107.79215711   63.62917565] 314.05365698757794
# [-299.04736138 -110.16770101   61.04216931] 315.5615137102864
# [-299.80912991 -112.62065382   58.36843704] 317.19487439600147
# [-300.6429469  -115.14570217   55.60616216] 318.9529554589479
# [-301.54771611 -117.73472319   52.75255617] 320.83402189919644
# [-302.51980274 -120.39263469   49.80892732] 322.8390030321378
# [-303.56188615 -123.09517707   46.7673996 ] 324.9631975926138
# [-304.66660218 -125.85718884   43.63260117] 327.20788354985604
# [-305.83712672 -128.65526942   40.39707467] 329.5689093228559
# [-307.07043602 -131.48810916   37.06064933] 332.0450284490404
# [-308.36052954 -134.35824599   33.62485075] 334.6337893437038
# [-309.71390144 -137.24053788   30.08212657] 337.3328894319683
# [-311.12039045 -140.14485085   26.43729893] 340.1388163946549
# [-312.58527196 -143.05041335   22.6849903 ] 343.0495756813129
# [-314.101449   -145.95935142   18.82843706] 346.0610664526921
# [-315.67452166 -148.85298561   14.86380832] 349.1720192053333
# [-317.29241845 -151.73794887   10.79749863] 352.37533709884025
# [-318.96720508 -154.58976271    6.62436428] 355.67274274224434
# [-320.68752655 -157.41198013    2.35121609] 359.056056239533
# [-322.45614218 -160.19264243   -2.02078499] 362.52318726222643
# [-324.27715564 -162.91926008   -6.49016616] 366.07270348548326
# [-326.1464333  -165.58729576  -11.05108528] 369.6986909593958
# [-328.05984248 -168.19184208  -15.69690575] 373.3947209119116
# [-330.02229358 -170.72119497  -20.42362048] 377.1593046002752
# [-332.03627539 -173.16672276  -25.22517344] 380.98962323635516
# [-334.09839329 -175.5237679   -30.09244711] 384.87874089873975
# [-336.2116244  -177.78376845  -35.01776805] 388.8233878560774
# [-338.3370217  -179.92890683  -39.98481838] 392.77762057285145
# [-340.43830904 -181.94632846  -44.97412309] 396.6992917924553
# [-342.60551105 -183.85191083  -49.99016057] 400.6733156559331
# [-344.83806975 -185.6419476   -55.02070781] 404.69323969342406
# [-347.13507239 -187.31301903  -60.05266696] 408.7518916086575
# [-349.49825823 -188.86163277  -65.07299603] 412.8439979411358
# [-351.92962346 -190.28499535  -70.06803243] 416.9643355922835
# [-352.92173462 -191.03266278  -74.66561837] 419.4771928411389
# [-353.86041626 -191.60447733  -79.14763405] 421.86432433723337
# [-354.86846179 -192.04241213  -83.52856229] 424.2496977943191
# [-355.95493446 -192.34932054  -87.79695226] 426.6354568633236
# [-357.11088626 -192.52855167  -91.93595563] 429.00708960016505
# [-358.3358607  -192.58349495  -95.93135022] 431.3578508340117
# [-359.6410042  -192.52066508  -99.77253389] 433.6931421366321
# [-361.00672421 -192.34204522 -103.43996815] 435.9877361884655
# [-362.44984977 -192.05750395 -106.92542688] 438.25395273387835
# [-363.94850095 -191.66836739 -110.20942195] 440.4643267146631
# [-365.51555799 -191.18639491 -113.28364344] 442.6287718247817
# [-367.13127372 -190.61322348 -116.13037058] 444.72244690239523
# [-368.80268056 -189.96116442 -118.74101772] 446.7507691483508
# [-370.48438326 -189.22681421 -121.09115719] 448.66330842157515
# [-372.14917114 -188.41562134 -123.16312192] 450.4311344824189
# [-373.83180947 -187.54279902 -124.9601274 ] 452.0886796241258
# [-375.52465482 -186.61634773 -126.47307405] 453.62796463818665
# [-377.21952011 -185.64452376 -127.69393402] 455.0413597955998
# [-378.90372374 -184.63214488 -128.61430379] 456.3162225329972
# [-380.56916733 -183.58788595 -129.22879291] 457.4468190726389
# [-382.20343691 -182.51652351 -129.53171587] 458.4224348701675
# [-383.79648662 -181.42495783 -129.51969483] 459.23644799416456
# [-385.33654962 -180.31796244 -129.19002346] 459.8805455923091
# [-386.81192343 -179.19974192 -128.54135185] 460.34711878518436
# [-388.21221932 -178.07544361 -127.57426384] 460.6311292389204
# [-389.52561541 -176.94750223 -126.28995915] 460.72581819031245
# [-390.74206483 -175.81973682 -124.69173343] 460.6275867052191
# [-391.85067319 -174.6931808  -122.78354187] 460.33155726398206
# [-392.84060632 -173.56599786 -120.57008471] 459.8323297762443
# [-393.70975788 -172.45669016 -118.06361235] 459.14289125469804
# [-394.44715372 -171.36368047 -115.27159793] 458.2591859376735
# [-395.03726515 -170.26292397 -112.19650905] 457.16293411861903
# [-395.47583183 -169.15672702 -108.84996394] 455.859219137287
# [-395.75863661 -168.04444464 -105.24389936] 454.3521878385387
# [-395.88233924 -166.9248512  -101.39115838] 452.64684962516816
# [-395.84451622 -165.79634282  -97.30543786] 450.7491262422463
# [-395.6436464  -164.6565756   -93.00107667] 448.66557634468
# [-395.27946094 -163.50349235  -88.49325662] 446.40411435581996
# [-394.75249372 -162.33434674  -83.79756493] 443.97305274135937
# [-394.0644154  -161.14665442  -78.9301762 ] 441.3817721525907
# [-393.05399844 -159.90676117  -73.88643842] 438.4772398986471
# [-391.85109054 -158.63645973  -68.70423481] 435.39652442405236
# [-390.50215261 -157.34328794  -63.40704675] 432.19351985792196
# [-389.01283613 -156.02502202  -58.01190694] 428.88010559011104
# [-387.38919884 -154.68056696  -52.5360503 ] 425.4686004789599
# [-385.63684387 -153.31203801  -46.99745321] 421.971847331013
# [-383.77908208 -151.8732588   -41.39943123] 418.39665566338624
# [-381.81769584 -150.39122254  -35.76624109] 414.76271371436
# [-379.76295506 -148.86450573  -30.11337425] 411.08400763759334
# [-377.62588888 -147.29171731  -24.45573585] 407.3746506132793
# [-375.41745058 -145.67234102  -18.80785953] 403.64848497953375
# [-373.14750946 -144.00880444  -13.18454234] 399.91902428878694
# [-370.82957186 -142.29791679   -7.59800765] 396.20009599209186
# [-368.47418858 -140.54218803   -2.06156656] 392.5046838748497
# [-366.09082615 -138.7454365     3.41173642] 388.84469700730386
# [-363.6944226  -136.90495927    8.81203204] 385.2337943329921
# [-361.29102687 -135.02892827   14.12626184] 381.68136525814106
# [-358.89582919 -133.11542172   19.34602245] 378.20055183731574
# [-380.36241225  -49.2425236    47.20579267] 365.32841626333663
# [-376.18858258  -47.33937748   51.42882294] 361.2929423861298
# [-372.2709078   -45.64555768   55.45544669] 357.6106595738804
# [-368.59447574  -44.1521633    59.29256821] 354.259111075734
# [-365.14603032  -42.84851012   62.94729006] 351.2177379379305
# [-361.90778384  -41.72677171   66.42475608] 348.4622923023679
# [-358.86271323  -40.77843842   69.72975574] 345.96960982042606
# [-355.99301771  -39.99604195   72.86608047] 343.7162545062907
# [-353.27887306  -39.37322699   75.83621963] 341.67723576880786
# [-350.70332608  -38.90313117   78.64273454] 339.83071236288276
# [-348.24565387  -38.58088564   81.2863808 ] 338.151573309878
# [-345.88940873  -38.40080568   83.76847586] 336.61921290581273
# [-343.61516444  -38.35873008   86.08887884] 335.21045654628915
# [-339.506989    -38.29492889   87.75209489] 331.94379478519375
# [-331.75785195  -38.08904329   88.23841484] 324.94425703264557
# [-324.09553335  -38.0571931    88.50653593] 318.05853327475836
# [-316.51634471  -38.19234491   88.56973936] 311.28388209075035
# [-309.01585354  -38.48767012   88.44104112] 304.6175583330491
# [-301.58896211  -38.93615748   88.13318245] 298.05676935634034
# [-294.23236629  -39.53051782   87.6592992 ] 291.6011158280512
# [-286.94409797  -40.26341959   87.03276077] 285.25209854469205
# [-279.72262184  -41.12726594   86.26687051] 279.0120830533086
# [-272.57182579  -42.11503401   85.37633271] 272.8894939433181
# [-265.48616002  -43.21720528   84.37267981] 266.8828776347582
# [-258.47705271  -44.42823341   83.2723161 ] 261.00919620248465
# [-251.54037136  -45.73739875   82.08636468] 255.26843430957825
# [-244.68690726  -47.1386199    80.83018753] 249.67686196311678
# [-237.92358724  -48.62388575   79.51737413] 244.2461867814371
# [-231.25618201  -50.18397823   78.16042944] 238.9862735079539
# [-225.76281235  -51.23048789   77.0287225 ] 234.76911421472371
# [-220.46924639  -52.2035117    75.86640067] 230.7519167858532
# [-215.19913771  -53.28320158   74.6480804 ] 226.8242536965065
# [-210.06657917  -54.46285657   73.41621452] 223.1012444580021
# [-205.08073452  -55.73829612   72.18140562] 219.594326891308
# [-200.24819224  -57.10312383   70.95228491] 216.3108740061539
# [-195.57583554  -58.5513676    69.73664292] 213.25787418257767
# [-191.07846129  -60.08481921   68.54487314] 210.45244029825034
# [-186.76046132  -61.69377938   67.38134329] 207.89566623903087
# [-182.63202561  -63.37678808   66.25243659] 205.59679357869382
# [-178.70589618  -65.13441511   65.16455378] 203.56742114382416
# [-174.98828176  -66.9603287    64.1197414 ] 201.8084744099175
# [-171.19241122  -68.83755341   63.04859081] 200.0517873557569
# [-167.41683063  -70.77136089   61.98164588] 198.39336251933713
# [-163.86559866  -72.76044014   60.96654522] 197.01276361151173
# [-160.55255127  -74.81268281   60.00667101] 195.9215641587306
# [-157.48813842  -76.92984641   59.10187357] 195.12383767391398
# [-154.68105948  -79.10995282   58.24932946] 194.6187604982146
# [-152.14078785  -81.3563338    57.44666189] 194.4085198774798
# [-149.87572426  -83.66997549   56.68940603] 194.49212616213728
# [-147.89436222  -86.05845135   55.97401289] 194.87249121289275
# [-146.20405522  -88.52373582   55.29391184] 195.54748967079644
# [-144.36684775  -91.00665031   54.56663239] 196.12979867506803
# [-142.70932554  -93.54871186   53.84768733] 196.90048594347326
# [-141.35750088  -96.17402906   53.15126995] 197.96454709728832
# [-140.31737478  -98.88724194   52.46808458] 199.31995763099349
# [-139.59320852 -101.69500606   51.78848581] 200.96523470840123
# [-139.18914304 -104.5991487    51.1003231 ] 202.89566332469337
# [-139.10600432 -107.61212292   50.39431054] 205.1129462572797
# [-139.34484213 -110.74035254   49.65853845] 207.615296529663
# [-139.90644841 -113.98741165   48.87956474] 210.3994353597028
# [-140.73395671 -117.34501023   48.03920153] 213.41497058024228
# [-141.41666993 -120.7211103    47.09676723] 216.31276057105993
# [-142.42299225 -124.22043644   46.0812722 ] 219.48835405697196
# [-143.7473617  -127.8525995    44.98069874] 222.94214528129726
# [-145.38681278 -131.61837342   43.77986329] 226.67042208926514
# [-147.3352963  -135.52092915   42.46478341] 230.67053654483567
# [-149.58375988 -139.56716062   41.0234178 ] 234.942070350578
# [-152.12856719 -143.75121773   39.43930947] 239.47899007509247
# [-154.95643243 -148.07911666   37.70171734] 244.27965010603438
# [-158.06209058 -152.54436163   35.7956102 ] 249.3384965608945
# [-161.43304676 -157.14729869   33.71011034] 254.6517560065856
# [-164.84233544 -161.78994585   31.43577001] 260.00314263432205
# [-168.46239927 -166.46011237   28.9399817 ] 265.4979409459933
# [-175.06257001 -171.2683592    25.76284549] 272.9955381428041
# [-182.04325308 -176.21385481   22.28667805] 280.87239862433455
# [-189.38788344 -181.28425266   18.50157018] 289.121277885664
# [-197.0787142  -186.46558316   14.40013973] 297.7328578842866
# [-205.10169932 -191.73982674    9.97601324] 306.6970348864029
# [-213.43993658 -197.08898123    5.22654282] 316.0015261279026
# [-2.22074348e+02 -2.02494234e+02  1.52666890e-01] 325.6313682581166
# [-230.99480128 -207.93108013   -5.24488934] 335.5730207910976
# [-240.18275862 -213.37714645  -10.95928562] 345.8079113345533
# [-249.62450422 -218.80730452  -16.98192739] 356.3179317550089
# [-259.30874129 -224.19476175  -23.30159796] 367.0845941418221
# [-269.22250996 -229.51244015  -29.90300936] 378.0869204114647
# [-279.35332719 -234.73277201  -36.76740252] 389.30269304267233
# [-289.6916352  -239.82760174  -43.87332821] 400.7101770655543
# [-300.16722826 -244.74663698  -51.18093654] 412.22501968871615
# [-310.68623974 -249.42519838  -58.63934064] 423.7321744943846
# [-318.049133   -252.42031601  -65.40347215] 431.78440506129397
# [-324.47568184 -254.66662889  -71.93124517] 438.6875957042431
# [-331.100513   -256.64301757  -78.47158211] 445.63432769412617
# [-337.9158767  -258.33410878  -84.99184392] 452.6055666586724
# [-344.9119819  -259.72524752  -91.45701861] 459.5801165105439
# [-352.08473993 -260.80438483  -97.83236047] 466.54219282789404
# [-359.41932297 -261.55881334 -104.07864747] 473.46605000570844
# [-366.90702256 -261.97940617 -110.15767629] 480.33249838298855
# [-374.53005441 -262.05641585 -116.02794867] 487.11390116019453
# [-382.23810612 -261.76846687 -121.63747168] 493.74771491984075
# [-389.90116249 -261.06324142 -126.90841227] 500.0843776833462
# [-397.60841931 -259.98476803 -131.83401732] 506.2176159458117
# [-405.33270988 -258.53047939 -136.37231671] 512.115395599343
# [-413.04522907 -256.70019562 -140.48275908] 517.7460875994802
# [-414.74829456 -252.88075427 -142.21649343] 516.9210187359955
# [-412.8050369  -247.80433887 -142.33984451] 512.0860733919885
# [-410.97823273 -242.52698555 -142.06207523] 507.13682211903176
# [-409.24553048 -237.06139998 -141.37730759] 502.0640187256191
# [-407.58554534 -231.42276434 -140.28254268] 496.8619920628988
# [-405.97519688 -225.62604124 -138.77678327] 491.524750745576
# [-404.39122285 -219.68735602 -136.86171879] 486.048032173619
# [-402.81112729 -213.62408492 -134.54208317] 480.43009666426383
# [-401.24200283 -207.40481972 -131.824673  ] 474.6710820038703
# [-399.65980727 -201.05197653 -128.71776904] 468.7734984268845
# [-398.02091397 -194.62782492 -125.23541275] 462.74352878217076
# [-396.31411401 -188.16014232 -121.39720457] 456.59845251330404
# [-394.51355798 -181.64318007 -117.21549365] 450.3256435001297
# [-392.61231116 -175.1034991  -112.71469089] 443.94646020294874
# [-390.61967487 -168.59784504 -107.93052472] 437.5115020260133
# [-388.57200197 -162.08174077 -102.88268933] 431.0465683660274
# [-386.4756061  -155.59345579  -97.60244793] 424.5907448875737
# [-384.31434682 -149.19974751  -92.12542371] 418.1741182573831
# [-382.10501805 -142.91935455  -86.48249698] 411.83269546209533
# [-379.86414055 -136.7715188   -80.70400092] 405.6013530959301
# [-377.61513605 -130.77319243  -74.81962284] 399.5190650530629
# [-375.45977245 -124.88804885  -68.85158554] 393.6746246052043
# [-373.42346051 -119.15268837  -62.82818839] 388.1164800939827
# [-371.49099644 -113.61620564  -56.77665295] 382.8572836893129
# [-369.69597373 -108.28700499  -50.71676965] 377.9366394642967
# [-368.07247353 -103.17126486  -44.66513021] 373.39256584101116
# [-366.65442574  -98.27198644  -38.63475351] 369.2606973376609
# [-365.54906024  -93.54373755  -32.62427525] 365.6294515545709
# [-364.78771404  -88.99521942  -26.63981938] 362.5346666237469
# [-364.32018953  -84.71707132  -20.70753392] 359.95746157393154
# [-364.1804413   -80.67377507  -14.81997572] 357.91683605673325
# [-364.38966357  -76.85903679   -8.97530047] 356.42884362858416
# [-364.96460898  -73.2669196    -3.17016813] 355.5050278942423
# [-365.91888354  -69.89017702    2.60035362] 355.1532536983109
# [-367.29584392  -66.7112213     8.34717441] 355.40778716856767
# [-369.18645182  -63.6990363    14.09101179] 356.34729700569653
# [-371.47346139  -60.88149153   19.82173594] 357.8605964362206
# [-374.15384415  -58.24888433   25.54578069] 359.93807969907033
# [-377.22253152  -55.79073355   31.26927475] 362.5679732693441
# [-380.67093792  -53.49764001   36.99716042] 365.7352476683675
# [-384.48837799  -51.36014109   42.73337306] 369.422739322646
# [-295.99875867   41.28406748   50.14599896] 269.1663015558343
# [-308.26706642   44.02684275   55.27792073] 282.20407469966415
# [-321.14850415   46.53310851   60.58676703] 295.9482488049657
# [-330.63297163   48.13680796   65.23388329] 306.24345327109233
# [-331.28243267   47.88824824   67.93220179] 307.4216052504947
# [-332.34834213   47.34277223   70.58161607] 309.03478252733527
# [-333.73214791   46.50855212   73.18059328] 310.9864286186546
# [-335.34239234   45.39279607   75.72525682] 313.1884644636217
# [-337.09539519   44.00269951   78.2101805 ] 315.5619260770709
# [-338.9129593    42.34495913   80.62829318] 318.0343880057844
# [-340.63603762   40.40129665   82.94800691] 320.4484267700159
# [-338.5128897    38.01813183   84.22531572] 318.94540275693413
# [-329.94541021   35.08292657   83.72540847] 310.8311499495906
# [-321.32838931   31.91667061   83.05119619] 302.70511102126994
# [-312.63050617   28.53649851   82.21427903] 294.5516678288479
# [-303.81971025   24.95877366   81.22501961] 286.3562528858815
# [-294.87349344   21.20066715   80.09550104] 278.1161751056166
# [-285.77340128   17.27925133   78.83817502] 269.83504945902797
# [-276.50288784   13.2115792    77.46534543] 261.52073038125053
# [-267.05094358    9.01468851   75.990262  ] 253.18932031174876
# [-257.58302247    5.64037785   74.45903738] 245.01337526116248
# [-248.25107313    2.86384225   72.90589488] 237.12808322558493
# [-2.38949069e+02 -3.79398339e-02  7.13222036e+01] 229.4557293259423
# [-229.19681853   -3.10171496   69.58368427] 221.52996481721397
# [-219.5083098    -6.26378721   67.85592667] 213.91500212223107
# [-209.88973291   -9.51304211   66.15563704] 206.6513206132342
# [-200.34925901  -12.83835959   64.49904282] 199.78355612800686
# [-190.90343992  -16.23213951   62.90409303] 193.3672741197361
# [-181.55801245  -19.68125276   61.38375186] 187.44648748172878
# [-172.32683533  -23.17590697   59.9523915 ] 182.07358298064614
# [-163.22531562  -26.70658969   58.62347749] 177.30032093341876
# [-153.72723549  -30.30410921   57.25826617] 172.6703267279815
# [-147.76815461  -32.90377661   56.816447  ] 171.4566537571928
# [-142.93411704  -35.28542483   56.68811267] 171.50991935835455
# [-138.18457825  -37.75687094   56.62340047] 171.96172743814685
# [-133.51216409  -40.30939716   56.62070633] 172.79593178814568
# [-128.92850878  -42.95346431   56.68684343] 174.01994338653338
# [-124.42706979  -45.67903679   56.81868342] 175.60930925943276
# [-119.84929454  -48.41664075   56.95887141] 177.37142025766454
# [-115.26475557  -51.19111571   57.13154104] 179.3646943629674
# [-110.75787619  -54.02679744   57.36326211] 181.65261064151264
# [-106.330534    -56.92171809   57.65227718] 184.20992690155524
# [-101.98886927  -59.88500749   58.00040625] 187.02117956626043
# [-97.72614372 -62.90021743  58.39883089] 190.0405093647167
# [-93.54403521 -65.9688132   58.8452115 ] 193.24117760494835
# [-89.20830537 -68.9847239   59.25701526] 196.35756976144634
# [-84.91692464 -72.0233021   59.69605494] 199.55815088426507
# [-80.71177042 -75.09958365  60.17154392] 202.85399452391718
# [-76.59428537 -78.21134523  60.6788189 ] 206.2162927157695
# [-72.56573011 -81.35854523  61.21370243] 209.61939511719086
# [-68.62681174 -84.53939487  61.77116031] 213.03729307892579
# [-64.68894134 -87.70687335  62.31844128] 216.3618499956491
# [-60.62903297 -90.78458321  62.81147841] 219.45091953279228
# [-56.67114133 -93.88180816  63.31515287] 222.49545730975248
# [-52.8174777  -96.99499487  63.82344614] 225.4749141821548
# [ -49.06849825 -100.12571928   64.33200421] 228.37524772762913
# [ -45.42541415 -103.27658384   64.83692612] 231.186019784218
# [ -41.88958324 -106.44792889   65.33340167] 233.8967218354736
# [ -38.25253292 -109.49862876   65.75475993] 236.29672193324635
# [ -34.68197979 -112.53079981   66.14698226] 238.5385366556075
# [ -31.24051256 -115.57486338   66.51900719] 240.66493025456427
# [ -27.92821756 -118.63473941   66.8666303 ] 242.67531376417298
# [ -24.74450835 -121.71820023   67.18709693] 244.57498112087717
# [ -21.69131419 -124.82448502   67.47408896] 246.36247345291162
# [ -18.72353832 -127.92483573   67.71269844] 248.0021510910446
# [ -15.68365016 -130.88211727   67.85643812] 249.33680147682645
# [ -12.7989229  -133.87055498   67.95708607] 250.58575258638066
# [ -10.06862826 -136.89676047   68.00971725] 251.7587126619744
# [  -7.48919162 -139.97245342   68.01136216] 252.87181268626153
# [ -12.44534982 -143.78102492   67.27078624] 254.92404116832398
# [ -18.03444764 -147.87356507   66.27120828] 257.1464193828905
# [ -24.01301813 -152.20267549   65.00452198] 259.5103415318101
# [ -29.84538569 -156.59327899   63.48104745] 261.81759474080576
# [ -36.27097552 -161.30584982   61.66598263] 264.4340352590777
# [ -43.26368841 -166.35473399   59.54342791] 267.4184953909871
# [ -50.7934285  -171.75305509   57.09968186] 270.82971614939765
# [ -58.83153856 -177.5077493    54.32081758] 274.72058375630945
# [ -67.34862357 -183.62411131   51.19486601] 279.14148180287435
# [ -76.31379174 -190.10384814   47.71160948] 284.13692440236616
# [ -85.49425344 -196.83531326   43.88108632] 289.58734748992515
# [ -94.66520179 -203.68542256   39.72127632] 295.3347693465609
# [-105.65201323 -211.05615541   34.85813484] 302.31747466617287
# [-121.86710163 -219.43144675   28.41532584] 312.2836961081599
# [-138.5382159  -228.1937495    21.45895744] 323.4320548550355
# [-155.63278274 -237.30944662   13.99423553] 335.73663680039857
# [-173.12355962 -246.73924814    6.02943899] 349.158087405639
# [-190.97905656 -256.44014216   -2.42052085] 363.64356654003683
# [-209.18272311 -266.3625734   -11.34023228] 379.13537507502554
# [-227.71049138 -276.45344685  -20.70612593] 395.5651649943284
# [-246.55026987 -286.6553487   -30.49247636] 412.8645443208959
# [-265.68687206 -296.90640461  -40.66656632] 430.95835940429424
# [-279.42436072 -304.26698877  -49.6995266 ] 443.94222922646156
# [-291.54998539 -310.51246121  -58.42478583] 455.40535381049847
# [-304.0006369  -316.55492097  -67.2969255 ] 467.25839859637864
# [-316.78440278 -322.34203645  -76.27796329] 479.46737122038616
# [-329.90844698 -327.8189905   -85.32503962] 491.99416433636526
# [-343.37966366 -332.92877511  -94.39068022] 504.7973864750145
# [-357.20365966 -337.61234746 -103.4225986 ] 517.832038846976
# [-371.38330946 -341.80835298 -112.36345132] 531.0485626438458
# [-379.73242465 -342.9948907  -119.17160385] 538.0776201373618
# [-376.46448574 -338.91820358 -121.87889774] 532.9042879164915
# [-373.60123725 -334.38440829 -124.27670588] 527.7463078650867
# [-371.15489662 -329.34171956 -126.34734235] 522.5648323348834
# [-369.08252352 -323.76640956 -128.05503183] 517.3013731817465
# [-367.33368465 -317.6519048  -129.36334475] 511.9053525886396
# [-365.86859984 -310.97676522 -130.24007229] 506.3251255085397
# [-364.64196603 -303.72318353 -130.65331755] 500.50943062549294
# [-363.50523102 -295.79578075 -130.53738796] 494.2762207598822
# [-349.99898893 -283.28061642 -126.09878982] 475.35854945528416
# [-334.9879335  -270.0684473  -120.82173464] 454.76145338892286
# [-320.68120865 -256.79354318 -115.4035693 ] 434.60892272912787
# [-306.95921531 -243.46089998 -109.83690725] 414.8080403442692
# [-293.43254841 -230.08178347 -104.05624135] 395.0710591058544
# [-280.05006347 -216.69710747  -98.0910208 ] 375.3886974432686
# [-267.00267261 -203.3535378   -92.02566814] 355.9369299190263
# [-254.90368045 -190.07083138  -86.01628099] 337.18449795593267
# [-242.91112968 -176.92999279  -79.92842675] 318.56489288698936
# [-231.01100856 -164.01150197  -73.81265274] 300.1282251420755
# [-220.3298597  -151.32194151  -67.89328525] 282.7152974685879
# [-210.05561187 -138.96247273  -62.0634437 ] 265.8014811081743
# [-199.9711112  -127.00334658  -56.33205495] 249.27914946170932
# [-191.47830545 -115.42272982  -50.90341775] 234.1838436885191
# [-183.4292642  -104.32185441  -45.64398809] 219.74332536989078
# [-175.98939274  -93.75740738  -40.600255  ] 206.12984704795156
# [-170.88954045  -83.60605885  -35.90593766] 194.6099698226411
# [-166.3704658   -73.96700072  -31.38842877] 183.949004513347
# [-162.90630845  -64.87103774  -27.0881695 ] 174.5723900745716
# [-161.65664116  -56.19939057  -23.01790358] 167.41733365595238
# [-161.27677157  -48.00103242  -19.07493253] 161.51262438297292
# [-162.26733891  -40.21686342  -15.24282736] 157.32059280260304
# [-165.55662748  -32.71304422  -11.46463762] 155.70684992380274
# [-169.80701345  -25.5482354    -7.68468979] 155.62674109804848
# [-175.05504637  -18.7068068    -3.87737155] 157.14456520867975
# [-1.82489404e+02 -1.20141453e+01  5.37804171e-02] 161.369034392648
# [-191.07905712   -5.50939336    4.12590143] 167.37043180608572
# [-200.56067849    0.79910094    8.35157567] 174.86694975391265
# [-210.94132273    6.92789418   12.7532216 ] 183.81190795508024
# [-222.61832586   12.95984466   17.39752873] 194.53990224193186
# [-235.73097642   18.96767364   22.34316096] 207.14265341967354
# [-246.36025484   24.05375746   27.04181173] 217.6181650078962
# [-254.48417138   28.0024608    31.3570794 ] 225.7997441234956
# [-263.56850389   31.66911323   35.80458245] 235.12617800533593
# [-273.56890392   35.10299876   40.41233928] 245.52975132873706
# [-284.40576641   38.30804711   45.19098631] 256.9093864219567
# [-167.44108212  102.70400133   35.15889252] 142.6156228240198
# [-190.42009908  108.74511765   40.5953241 ] 166.9147538525591
# [-213.99123369  114.40458051   46.37333849] 191.88944900905048
# [-237.14754741  119.26094444   52.26005897] 216.42650489550059
# [-248.93495663  119.12920117   55.66492375] 228.56639713969145
# [-260.88888405  118.52577838   59.1843189 ] 240.88567770771567
# [-272.85547808  117.42046408   62.79130279] 253.25327999335443
# [-284.69781491  115.79393935   66.45980297] 265.5550864525565
# [-296.2949353   113.63756594   70.16499146] 277.69303277819495
# [-303.35490751  110.14878048   72.8605751 ] 285.25336412747197
# [-300.53079522  104.35910963   73.1518005 ] 282.6666185829708
# [-297.11076718   98.15939095   73.27379986] 279.55794597327406
# [-293.1351146   91.6182404   73.2485516] 276.00861570506225
# [-288.54315234   84.76723961   73.07053982] 271.98904415543143
# [-283.29724233   77.64490374   72.73899003] 267.4943159889351
# [-277.33205737   70.30526239   72.24477454] 262.49491266680997
# [-267.70438073   64.40384702   70.7910257 ] 254.33659242129508
# [-257.89317372   58.42270752   69.27213669] 246.1706047963929
# [-247.37463268   52.2543181    67.55781569] 237.4668795353298
# [-236.49341549   46.01170577   65.75405129] 228.62451092125715
# [-225.45353089   39.76461787   63.92925603] 219.89454263837933
# [-214.26355748   33.5301087    62.09805951] 211.32421562565372
# [-202.93061733   27.32442969   60.2741674 ] 202.96465698305335
# [-194.06229198   22.42529724   59.12592923] 197.52812782731786
# [-187.55600146   18.71578078   58.60868705] 194.8016271939626
# [-180.97617646   15.04821611   58.09985753] 192.2644107577089
# [-174.55746698   11.41206454   57.67395399] 190.17371554456838
# [-168.3086312     7.79745528   57.33885261] 188.55077258082483
# [-162.2183239     4.20201401   57.09501671] 187.39315729548792
# [-156.28346718    0.6192605    56.94527494] 186.70533061223892
# [-150.32815651   -2.91146311   56.83368442] 186.3015214091562
# [-144.33994128   -6.37690365   56.7551838 ] 186.16527409168776
# [-138.49897598   -9.82720959   56.77153802] 186.4890520852963
# [-133.07243067  -13.28292943   56.96247291] 187.52784554189958
# [-128.83412621  -16.79346538   57.55057434] 190.00028810308882
# [-124.64829496  -20.27994868   58.19303149] 192.7527312352345
# [-120.29357798  -23.62133915   58.79700679] 195.4962621944115
# [-115.98134641  -26.94483442   59.4467336 ] 198.46866155748262
# [-111.69334999  -30.24143515   60.13170635] 201.62498216801413
# [-107.4461587   -33.55530231   60.86498799] 204.98414025304544
# [-103.21339317  -36.87751945   61.63488251] 208.49677371842571
# [-98.86337423 -40.12789636  62.38348094] 211.98162381452565
# [-94.4128453  -43.32479362  63.11840582] 215.4474541786705
# [-89.95871197 -46.53504071  63.88100516] 218.99956167591958
# [-85.48754136 -49.7665874   64.66940527] 222.61724266032093
# [-80.98554782 -53.0302801   65.4834811 ] 226.28502277630338
# [-76.39590539 -56.29846422  66.3024336 ] 229.93102918117538
# [-71.5877995  -59.4507529   67.06031948] 233.36301038842717
# [-66.72911218 -62.63253277  67.84119082] 236.80414225041216
# [-61.80444037 -65.84765053  68.64503147] 240.24297296849792
# [-56.79875745 -69.09873438  69.47232957] 243.67064013292497
# [-51.69579218 -72.38729075  70.32387261] 247.08016036110158
# [-46.30602336 -75.50892202  71.09936584] 250.19361897315613
# [-40.81005841 -78.64970402  71.89952241] 253.27961145183193
# [-35.19938832 -81.81119095  72.72788921] 256.34249339488105
# [-29.45942388 -84.99083111  73.58639049] 259.38318307418564
# [-23.57569868 -88.18050341  74.4754037 ] 262.4001082353207
# [-17.4156578  -91.21585202  75.32483475] 265.2043833114352
# [-11.08218811 -94.20503993  76.19324916] 267.9549355073728
# [ -4.59474072 -97.17621616  77.09925711] 270.70282270123965
# [   2.06129777 -100.13550172   78.0510326 ] 273.4707461532456
# [   8.89201196 -103.06334721   79.04637988] 276.25732830384413
# [  15.99728176 -105.80889097   80.02974461] 278.91922939989
# [  23.31855196 -108.4165284    81.02819453] 281.5363929962444
# [  30.8151897  -110.97050597   82.08325918] 284.2246007383952
# [  38.48878074 -113.45255673   83.1930431 ] 286.9869935788541
# [  43.36627147 -116.31267985   84.29523913] 289.89345192306024
# [  47.8628154  -119.14783724   85.33607873] 292.65347229035734
# [  52.371878   -121.87147274   86.30505257] 295.2245146019494
# [  56.5682254  -124.68940859   87.24163897] 297.7580074560869
# [  60.45088873 -127.62504598   88.13585909] 300.25650207649073
# [  64.01955751 -130.69856123   88.97556879] 302.72051769640797
# [  67.30766103 -133.90459139   89.74359936] 305.13549377960027
# [  70.54997694 -137.02662928   90.38136281] 307.33799362605214
# [  73.42921732 -140.33722496   90.92224261] 309.5052781811519
# [  75.9552151  -143.86347219   91.35383791] 311.65072381938063
# [  78.13232212 -147.62453176   91.65924778] 313.78048631149767
# [  76.83525348 -152.28016497   91.30747801] 315.3578296196983
# [  64.37899571 -159.51511872   88.81765347] 315.3206962796784
# [  51.82495356 -167.20484489   85.89376378] 315.89664816636986
# [  38.40899834 -175.73088167   82.44436221] 317.3376199291717
# [  24.18717096 -185.10951404   78.44943756] 319.83973084130906
# [   9.20992875 -195.34689815   73.88919206] 323.58622269384733
# [  -6.46966708 -206.44209927   68.74776909] 328.7450066481335
# [ -22.76330391 -218.35898828   63.01658567] 335.4339484193738
# [ -38.94329446 -230.54856886   56.76886199] 343.23082068688143
# [ -62.67008481 -245.25640754   48.12279331] 354.68458353171263
# [ -88.73771372 -261.28272079   38.2908106 ] 369.4323722132871
# [-115.3403789  -278.13639192   27.72475929] 386.9966168040352
# [-142.44707829 -295.74104582   16.43884061] 407.22389734519305
# [-170.03116275 -314.01131826    4.4547684 ] 429.92152009800816
# [-198.0741722  -332.85217196   -8.19916004] 454.8740884188095
# [-226.56609746 -352.15914279  -21.48769887] 481.85709147885535
# [-245.64077833 -366.42351513  -32.67452398] 501.3474171771343
# [-263.5749896  -379.88155909  -43.79700408] 520.271676972606
# [-281.92946315 -393.29051665  -55.21892477] 539.9614185224697
# [-300.74579853 -406.55220048  -66.89858138] 560.3353716112246
# [-320.06918203 -419.56128084  -78.78747679] 581.3092874871911
# [-339.94977238 -432.20488661  -90.8305217 ] 602.7970785187878
# [-342.20652599 -435.2669227   -97.2219504 ] 606.6118555561453
# [-337.71332086 -434.1156453  -101.16208188] 603.1723929873407
# [-333.85936997 -432.38022536 -104.92101145] 599.6882797050308
# [-330.678577   -430.00167698 -108.47768861] 596.1044342583616
# [-328.19709283 -426.9114911  -111.80447385] 592.3547611863128
# [-326.43846763 -423.0327157  -114.86863453] 588.3668992041329
# [-303.29440304 -407.29448826 -110.53133125] 562.2422078766984
# [-280.16497899 -390.90137352 -105.73860843] 535.7489141320863
# [-257.77735244 -374.07752015 -100.74674269] 509.4698835975299
# [-236.01024813 -356.80276095  -95.54774087] 483.3060402237793
# [-214.57545662 -339.05216228  -90.09227067] 457.08613070087716
# [-192.51347324 -320.21354726  -84.10819942] 429.8307880720526
# [-165.99473314 -297.87705784  -76.43627001] 397.7969836602992
# [-140.47916967 -275.78579347  -68.91452068] 367.0081401555926
# [-115.1083942  -253.91532713  -61.39585374] 337.23873251521286
# [ -89.43924065 -232.35309585  -53.86858673] 308.69781561009216
# [ -65.35454187 -211.40233296  -46.82604928] 282.4369137371955
# [ -41.03497883 -191.07255585  -39.95545596] 258.36803085814734
# [ -18.30846413 -171.62994494  -33.68913773] 237.35232719663483
# [  -1.20638138 -153.66976361  -28.77586187] 219.7024053523125
# [  12.99746187 -136.88882209  -24.62596425] 204.49229049217448
# [  26.74909539 -121.24009836  -20.85380482] 191.86555239272644
# [  39.10845815 -106.79463224  -17.61764919] 181.68677384127503
# [ 49.77880867 -93.6011874  -14.94964606] 173.66386424095853
# [ 59.32566466 -81.57450578 -12.75368324] 167.66258780454967
# [ 67.20634619 -70.60754889 -11.04165167] 163.00536855770287
# [ 73.09886031 -60.62778834  -9.7830834 ] 159.02667106204277
# [ 78.00990221 -51.48712488  -8.8370187 ] 155.9120498233936
# [ 81.43815524 -43.06098267  -8.17893817] 152.9740682209393
# [ 83.43704321 -35.19758658  -7.73322254] 149.90206847437398
# [ 81.36069329 -27.426932    -7.40682523] 144.03389849307416
# [ 72.46756025 -19.37355352  -6.99232536] 132.5363489512664
# [ 63.60316538 -11.19593179  -6.33195723] 121.04703253775953
# [52.81486869 -2.79523715 -5.38150655] 107.85131595597642
# [41.89712913  5.81079355 -4.14736378] 94.52928731483317
# [31.06263187 14.54077331 -2.666508  ] 81.41518073216884
# [18.53386995 23.5866503  -0.82114215] 66.94877402264973
# [ 4.55283504 32.77283275  1.38039142] 51.687661712785676
# [-15.04466804  42.23346278   4.32706423] 32.36673670329417
# [-35.17943614  51.86216175   7.70653524] 19.498421552420083
# [-56.65808688  61.74916556  11.61096723] 27.975291446755023
# [-78.9441392   71.74071376  15.97135604] 49.21158968097247
# [-101.73524895   81.69231217   20.72711245] 73.41718212457008
# [-123.61225741   89.77239767   25.39136953] 96.59161700015423
# [-145.14162198   96.35381167   30.08444332] 119.12053027292815
# [-65.25423149 123.49584956  16.69262864] 98.5386664585622
# [-94.44524965 136.06125175  22.36910496] 119.13051752621735
# [-124.73360503  148.01095939   28.46166472] 144.26256741316618
# [-148.96276562  154.31013338   33.25523637] 163.94774788222193
# [-172.24383532  159.07000912   37.99552361] 183.15657440671467
# [-195.05855152  162.69469785   42.8052274 ] 202.1963868692968
# [-217.32462389  165.17540657   47.67205396] 220.86781676285122
# [-234.65655843  165.10635511   51.59551527] 234.72939561525547
# [-241.98566695  161.08449721   53.35031647] 238.53768412318934
# [-247.94037824  156.04011702   54.89240713] 240.95432122071264
# [-252.49495374  150.04461474   56.22692533] 242.08611653244412
# [-255.79665706  143.27108828   57.40211375] 242.24640880266455
# [-255.6915085   135.84537736   57.90071412] 239.6418784186805
# [-249.32183277  128.12957421   56.97551611] 231.7826753636062
# [-242.33198754  120.13707787   55.99399031] 223.7749752862753
# [-233.97117194  111.61374762   54.78159393] 214.8904094474541
# [-225.12444708  102.90683477   53.57646935] 206.18152402655494
# [-215.8103867    94.02921608   52.39867255] 197.75436801033374
# [-207.57331269   86.43766763   51.6075773 ] 191.63185289074957
# [-200.66912875   79.97805441   51.26579038] 187.9806097763261
# [-193.54671506   73.49516417   51.00834193] 184.9421969937964
# [-186.74921044   67.06917406   50.98595063] 183.10188223231694
# [-180.23200789   60.68550583   51.18985903] 182.41684988666378
# [-173.98777689   54.33095034   51.61923495] 182.86294293867203
# [-167.85312411   48.01932876   52.22219345] 184.2331422236763
# [-163.02415556   41.58650952   53.36463798] 187.72370318628555
# [-159.14502166   35.18605693   54.91920455] 192.8790860803301
# [-155.39111157   28.96264229   56.60956985] 198.704006189377
# [-151.71935075   22.92645528   58.40157055] 205.012148274191
# [-147.91223366   17.1431117    60.19798313] 211.42357814945973
# [-143.96901062   11.6462313    61.9679409 ] 217.7869394741208
# [-139.99512988    6.41650152   63.72098128] 224.07833194509547
# [-135.98566036    1.45703991   65.43049695] 230.16569923773227
# [-131.90399971   -3.20465104   67.055558  ] 235.88697792858073
# [-127.39648051   -7.42792061   68.43853988] 240.74054857470423
# [-120.09206669  -13.42804168   69.4998666 ] 243.7518217153107
# [-112.60030917  -18.99694006   70.42194197] 246.26907616442034
# [-105.27476555  -24.00962275   71.24381115] 248.44638110784663
# [-97.8431578  -28.44350319  71.86283938] 249.95773260197058
# [-90.13196051 -32.37149712  72.2390659 ] 250.6726108416229
# [-82.70013986 -35.71153341  72.47009648] 250.92859895747324
# [-75.5734982  -38.46740068  72.53972547] 250.68387075311742
# [-68.79705245 -40.69076721  72.45381733] 249.95772154672463
# [-61.91801651 -42.47714267  72.12896598] 248.51154704878056
# [-55.32012623 -43.81006247  71.6358965 ] 246.57798714749146
# [-49.20913401 -44.72903795  71.01844152] 244.28940716929932
# [-43.60678362 -45.30387355  70.29273341] 241.69178503672504
# [-38.40474931 -45.60672189  69.455955  ] 238.78155046189838
# [-33.26402143 -45.69305747  68.46947801] 235.47137421558512
# [-28.67858362 -45.6207617   67.44031083] 232.04178913312705
# [-24.63067914 -45.46650999  66.39160739] 228.55008821971106
# [-21.09280024 -45.30332475  65.34703472] 225.05591340630724
# [-17.64594328 -45.17244129  64.2756443 ] 221.49855185465512
# [-14.49942718 -45.13383121  63.24021991] 218.03432935714315
# [-11.75217018 -45.26029758  62.28981784] 214.78565148623332
# [ -9.33711573 -45.61806182  61.45384833] 211.8347673108808
# [ -7.03854831 -46.22589167  60.73530096] 209.2089393007185
# [ -4.57639534 -47.07315182  60.13202532] 206.92599250803315
# [ -2.23558684 -48.24821833  59.71821449] 205.17322161094594
# [  0.07508527 -49.76890157  59.51258471] 204.01861608162582
# [  2.44966564 -51.63437941  59.5282503 ] 203.51784661257312
# [  5.45072419 -53.77378728  59.75558308] 203.66402125530914
# [  8.7207148  -56.22512433  60.23846084] 204.57746231176446
# [ 13.91014969 -59.8291337   61.45174538] 207.3474117248699
# [ 20.43505093 -64.22897927  63.28228125] 211.72149001245876
# [ 27.52588354 -68.76152833  65.4252288 ] 217.01189855929331
# [ 35.20082508 -73.41195779  67.89301226] 223.26011941297432
# [ 43.49100139 -78.2843596   70.74950882] 230.6296447060542
# [ 52.43904833 -83.32364267  73.98487227] 239.10733736551586
# [ 62.0825499  -88.41737328  77.5617604 ] 248.613005598807
# [ 72.43322519 -93.35355279  81.39539295] 258.950809320999
# [ 83.48280413 -98.26994736  85.54792942] 270.27775671796974
# [  95.23921568 -103.10159529   89.99101435] 282.5312496680239
# [ 107.69775257 -107.77886407   94.68989032] 295.6313911894093
# [ 118.6023684  -112.46244706   99.24433974] 308.6692432607804
# [ 124.19555403 -118.38895241  103.226101  ] 320.8116804146989
# [ 129.45494259 -124.49138228  107.08000058] 333.07746711348
# [ 134.35240391 -130.77240905  110.74219775] 345.3404660615769
# [ 138.94083545 -137.14171146  114.13500754] 357.42231815407433
# [ 143.34671283 -143.35245334  117.1537576 ] 369.0382629400544
# [ 147.17726099 -149.76608666  119.77779856] 380.21842019024035
# [ 150.39607789 -156.40324696  121.9467229 ] 390.84508044312963
# [ 150.01741604 -164.15693617  123.00729503] 400.02503009491863
# [ 131.74027255 -177.43411481  119.77575142] 404.4803175858094
# [ 113.07026067 -191.29116045  115.61330587] 409.3829530462115
# [  93.00901722 -206.35502027  110.36502205] 414.953867196996
# [  71.60406657 -222.66211846  104.01107763] 421.4632275072072
# [  48.90524455 -240.24084955   96.54232708] 429.2106560655792
# [  25.1482494  -258.95958652   87.98852328] 438.40581300443404
# [  -4.61995329 -280.25287032   76.96385158] 449.94378266308627
# [ -39.34472163 -304.37443069   63.7746333 ] 465.58640026949723
# [ -74.90493928 -329.86227594   49.51689596] 485.04112921095685
# [-111.25104758 -356.66234835   34.24684432] 508.37105163077473
# [-148.33853278 -384.70752273   18.03003415] 535.5475216199632
# [-185.84337884 -413.74408631    1.01823372] 566.2266437647097
# [-207.71599868 -434.14359698  -12.19047586] 586.5088106521147
# [-229.96404299 -454.99890254  -25.7978688 ] 608.3065844531097
# [-252.62744438 -476.23150322  -39.74691983] 631.6215343768306
# [-275.75735232 -497.75244247  -53.97888175] 656.4312797705028
# [-297.54440494 -518.32193395  -67.86022987] 680.8834418274364
# [-290.09106965 -520.67922689  -72.63381633] 677.452937637709
# [-283.28113197 -522.78605867  -77.28359233] 674.471292022692
# [-277.15046104 -524.60360635  -81.80029568] 671.9264319050797
# [-271.74098428 -526.07409874  -86.17446863] 669.7819740286106
# [-252.71672766 -517.04702835  -85.79940238] 653.008919728504
# [-222.89807112 -499.68063509  -81.52593444] 625.0982406049211
# [-193.69738792 -482.04411813  -77.03658768] 598.1447095594875
# [-165.00299481 -464.06552526  -72.34972039] 572.0930836774198
# [-135.19312734 -443.3146751   -66.9123555 ] 544.2327984098381
# [-101.52257501 -416.11402599  -59.74224788] 510.62025591589423
# [ -67.48265378 -388.62974209  -52.27498398] 478.57639560559727
# [ -32.77389641 -360.86722061  -44.53971603] 448.54868321338284
# [   2.57808429 -332.89414371  -36.6572834 ] 421.25327689954275
# [  25.57128103 -305.50477116  -31.59165185] 396.7633896898359
# [  49.95222264 -278.09212776  -26.16524378] 374.54296161280274
# [  75.01938525 -251.00784192  -20.67761657] 355.47265430152856
# [ 101.42235543 -224.53040103  -15.15252431] 340.6595369548807
# [ 124.32684975 -199.93101807  -10.68951484] 329.7928232876766
# [ 136.24549568 -178.93597661   -8.63375704] 319.54253831024414
# [ 148.41536224 -159.35472939   -6.77153898] 312.1489903390409
# [ 160.33934548 -141.67277133   -5.30580296] 307.63740146217344
# [ 171.46829606 -126.27754367   -4.40318667] 305.6688247398169
# [ 180.58226248 -113.37186902   -4.23385359] 305.0771671185731
# [ 187.71438989 -102.92464326   -4.74924866] 305.2986401476132
# [192.95271987 -94.50320062  -5.82055615] 305.6544007744056
# [195.55992099 -87.82405416  -7.38865212] 305.0335470123158
# [196.60742358 -82.2772985   -9.20647656] 303.6695528880695
# [196.25951203 -77.4646239  -11.14527795] 301.33020073071805
# [194.6622255  -73.09570791 -13.10189312] 297.89250412925315
# [189.77189928 -67.94072853 -14.8435932 ] 290.91601013494983
# [180.77671453 -60.59810348 -16.01697652] 278.9437125792036
# [172.15156911 -52.94816269 -16.86888999] 266.8366606399181
# [164.87724198 -44.85797638 -17.43172532] 255.4932719129651
# [157.51883891 -36.49724128 -17.74523654] 243.8594830933549
# [145.10874342 -25.0106413  -17.12304204] 226.3177818079474
# [130.30543531 -11.42263158 -15.76262265] 205.9617867893591
# [116.59239752   2.27284493 -14.18639596] 187.11728900085183
# [102.73897701  16.20396189 -12.33846566] 168.9208162500365
# [85.4592113  31.242917   -9.81107978] 148.42085153846975
# [62.52594555 47.86647317 -6.24051201] 124.27823926533135
# [39.56333845 64.35304652 -2.38143601] 103.89471926966634
# [16.29041231 80.63484105  1.76131822] 89.4241660968866
# [-8.39616322 96.23713561  6.25818649] 82.87668881768438
# [-36.58075566 110.18485451  11.31896471] 85.18890803743389
# [ -1.1222758  131.21988346   0.82095254] 129.98871737583556
# [-29.57068458 149.3870679    5.65027057] 134.94367994293995
# [-59.42170536 164.57844343  10.74822198] 145.5964976097797
# [-89.76717665 177.78722639  16.08198619] 161.41034350217174
# [-121.19800812  189.32096718   21.81312532] 181.19083905887726
# [-148.49769686  196.91087596   26.89363365] 199.73648766008438
# [-169.39380049  199.86035161   30.83430087] 213.41865224612945
# [-188.64432435  200.56883454   34.64646365] 225.59877190280113
# [-205.99740642  199.04869196   38.29862881] 235.98418440545422
# [-219.87835463  195.23020756   41.46271117] 243.37736489227822
# [-222.561864    188.04442329   42.37596475] 241.17591486971392
# [-223.54767681  179.79939727   43.12586695] 237.4134869325988
# [-222.25272587  170.34524578   43.58901585] 231.64356114187348
# [-219.05881374  160.00041217   43.85773165] 224.46794536559096
# [-213.66726904  149.34581076   43.83901905] 216.06273247413512
# [-206.42916066  139.15790978   43.56725133] 207.14906522101046
# [-198.47422646  128.97775796   43.33448527] 198.5246651203332
# [-190.24017145  118.98381411   43.23923648] 190.7910154378344
# [-182.01420485  109.25302611   43.34471106] 184.36070253247075
# [-173.83614083   99.78614744   43.65079546] 179.35464843783151
# [-167.16841826   89.77435561   44.63682924] 177.19327356670516
# [-161.08161158   80.19906483   45.94751818] 177.19505506308707
# [-155.43132763   71.22439914   47.49571241] 179.04697479664532
# [-150.23116736   62.84125081   49.25092445] 182.49395972066623
# [-145.10757279   55.06975355   51.06371086] 186.84355503743143
# [-140.28423529   47.93331815   52.95150267] 192.01034469979206
# [-134.94669259   40.32196151   54.83356127] 197.2228496439645
# [-127.33951266   30.38579154   56.55287754] 201.41462301628783
# [-119.19243643   20.99598263   58.09359267] 205.40165798630852
# [-111.07087007   12.40380491   59.53391722] 209.37963658346698
# [-103.1303234     4.67566775   60.86514723] 213.205445281253
# [-95.37904333  -2.20021359  62.05395984] 216.6710795160033
# [-87.18456158  -8.4884298   62.95321482] 219.24479811018625
# [-79.03905037 -13.97059834  63.62667137] 221.12103460058145
# [-71.18367888 -18.65810216  64.12069434] 222.40620739322296
# [-63.60060481 -22.56710319  64.41235392] 223.02069485933407
# [-56.65642382 -25.98484599  64.6704674 ] 223.40231542956423
# [-50.4605807  -28.80683607  64.87824111] 223.4986740738443
# [-44.58993669 -30.99264405  64.89587437] 222.95932401767487
# [-39.0529126  -32.60659223  64.73755347] 221.84985602657636
# [-33.55357028 -33.80417443  64.38018413] 220.15920985828322
# [-28.24259721 -34.55341105  63.85301267] 218.00123639761577
# [-23.27963121 -34.88352202  63.20466732] 215.5277517912341
# [-18.65643069 -34.84901785  62.45237153] 212.81359799268344
# [-14.19492798 -34.56483165  61.60398049] 209.9235558371289
# [ -9.96554102 -34.05548761  60.68898215] 206.9498693230298
# [ -6.08998429 -33.32952791  59.73584642] 203.9616351881458
# [ -2.55426276 -32.44379658  58.76307462] 201.00651704068278
# [  0.7409529  -31.48304724  57.78786294] 198.13388798515308
# [  3.77960516 -30.48734228  56.82990291] 195.37459683489618
# [  6.49296788 -29.47136141  55.90288943] 192.72627469685762
# [  8.91423625 -28.48036098  55.0169463 ] 190.18965987109266
# [ 11.12735277 -27.57674598  54.18580408] 187.78267540008812
# [ 13.14500099 -26.78583994  53.4173242 ] 185.4969320747798
# [ 14.9523247  -26.12186718  52.71682807] 183.31562946947795
# ...
# [-228.69255583  133.48308585    4.65359209] 320.60589031338463
# [-210.71702368  119.60491142    3.92605072] 317.8791979127405
# [-192.93359861  105.43795356    3.15364622] 315.61812014308424
# [-175.36496502   90.93076737    2.33892028] 313.8401769699931
# [-157.53566794   76.79706044    1.47304183] 311.77579511764
# [-140.29815086   62.37771987    0.58226771] 310.4272016824492
# [-123.52734245   47.85712481   -0.33183338] 309.55105511403696
# [-106.86878246   34.05862211   -1.26903045] 308.34769418301516
# [-91.01718771  20.26567202  -2.20502305] 307.7041035280445
# [-75.95623699   6.49389715  -3.13352591] 307.53140401999445
# [-61.43740209  -6.54906741  -4.04691481] 307.1321216708807
# [-47.7769062  -19.26417266  -4.92996836] 306.92038362309756
# [-35.00500456 -32.05554861  -5.78062443] 307.1190434651998
# [-22.93637096 -43.72991227  -6.57623699] 306.74811364880713
# [-11.74049545 -55.60298664  -7.327319  ] 306.7587359076347
# [ -1.26283385 -66.68431715  -8.01179265] 306.3307198572678
# [  8.55274444 -77.74087271  -8.64279039] 305.9231389162056
# [ 18.3963022  -84.49403455  -9.1203521 ] 302.0101147589081
# [ 27.53688857 -91.51109297  -9.52522284] 298.3014201408659
# [ 35.98519876 -98.18962475  -9.8365012 ] 294.36718686381386
# [  43.77849701 -104.21758245  -10.04016559] 289.9663085229513
# [  51.03464381 -110.30922578  -10.16208439] 285.527265041785
# [  57.79098113 -116.39279518  -10.20063146] 280.9815519107425
# [  64.07514825 -122.37395322  -10.15296096] 276.25332949960136
# [  69.8374575  -127.6721988    -9.99185844] 270.988771923767
# [  75.19423503 -132.89288838   -9.74700037] 265.54034623662494
# [  80.16422696 -137.99755681   -9.41905077] 259.8810773727057
# [  84.76305956 -142.95253151   -9.00917474] 253.99071630493088
# [  89.0036105  -147.72805201   -8.5190607 ] 247.85496174797262
# [  92.89642293 -152.29749983   -7.95093742] 241.46464953715594
# [  93.70432191 -155.78333462   -7.183743  ] 236.3685512202783
# [  93.20701149 -158.71750583   -6.30950381] 231.67782281600674
# [  92.40991887 -161.39262566   -5.37995155] 226.85619563655396
# [  91.32231663 -163.79308209   -4.40117746] 221.91750526660243
# [  89.95244953 -165.90443835   -3.37967787] 216.8794729526172
# [  88.30769089 -167.71324879   -2.32232226] 211.76372185956788
# [  86.39464471 -169.20706597   -1.23631986] 206.5961158597892
# [ 8.42191587e+01 -1.70374292e+02 -1.29181955e-01] 201.4068182044659
# [  81.78646092 -171.20424266    0.99131652] 196.23068723749185
# [  79.10118524 -171.68712215    2.11717914] 191.1074364155999
# [  76.03935339 -171.36075978    3.27083376] 186.0512695763557
# [  72.69573541 -170.53710628    4.42192858] 181.1869413083766
# [  69.099097   -169.30292007    5.55542202] 176.59343647825955
# [  65.25179748 -167.65469643    6.66240844] 172.3443819689376
# [  58.81356667 -166.31481098    7.67793115] 170.91177297371902
# [  50.86203689 -164.99894475    8.60209199] 171.18927218472348
# [  42.75810934 -163.30000156    9.45625331] 171.79790748258742
# [  34.30647707 -160.87704788   10.25365128] 172.97420307127933
# [  25.41738136 -157.58201162   10.99429196] 174.90026068103438
# [  16.38189831 -153.89753591   11.64338863] 177.29048726477473
# [   7.20881811 -149.82846634   12.19561852] 180.13537531027313
# [  -2.09303417 -145.3800613    12.64641053] 183.41960675869356
# [ -11.51478655 -140.55805033   12.99199623] 187.1228861450739
# [ -21.48120148 -134.67099609   13.25984244] 191.89963808527423
# [ -31.79531388 -128.06996348   13.42776342] 197.46973835123987
# [ -42.23453082 -121.11689059   13.47787477] 203.46147269024792
# [ -52.79013124 -113.82184633   13.40965338] 209.8267865628698
# [ -63.45333047 -106.19544161   13.22359992] 216.51780629242822
# [-74.6806005  -97.53351797  12.94250141] 224.29453296140625
# [-86.35422336 -88.07059876  12.55612947] 232.91594693234904
# [-98.14578203 -78.32506025  12.05147057] 241.77010313180784
# [-110.04507933  -68.31198528   11.4331813 ] 250.8011613192819
# [-122.04155192  -58.04696188   10.70697908] 259.9573966713813
# [-134.90656219  -46.39289117    9.89829873] 270.5713313779954
# [-147.98560749  -34.39107169    8.99071406] 281.4149558989893
# [-161.16548356  -22.21251136    7.9902874 ] 292.2581945489263
# [-174.4322207   -9.8770006    6.9069085] 303.0544196831734
# [-188.12368412    3.13109442    5.75566813] 314.4012905022908
# [-202.41942991   17.027037      4.5449089 ] 326.5662138327378
# [-217.38759936   29.93771997    3.22776248] 338.0298889087847
# [-232.34707933   42.89426297    1.87463042] 349.2276697047502
# [-247.27405052   56.03477749    0.50290213] 360.2641794453004
# [-263.01871074   70.09700857   -0.88773297] 372.2269103588431
# [-278.66348882   84.21981508   -2.2740898 ] 383.8990000598968
# [-294.18911747   98.39847303   -3.64274023] 395.27619891681354
# [-309.57747107  112.62845236   -4.98075652] 406.3565422956944
# [-325.35364734  127.41244627   -6.28473106] 417.8569939229536
# [-341.12296272  142.33333782   -7.53819633] 429.2279910830227
# [-356.70549783  157.22994917   -8.72726451] 440.25314119982545
# [-372.08313756  172.09925789   -9.84145003] 450.93700277617995
# [-387.40025997  187.1577466   -10.87331727] 461.55730370982036
# [-402.63512609  202.36166872  -11.81496521] 472.0840524500937
# [-417.60825049  217.47762425  -12.65712183] 482.2439768723565
# [-432.30375816  232.50484637  -13.39357182] 492.048469247528
# [-446.68047101  247.48134362  -14.01846568] 501.52917582020604
# [-460.62807852  262.51086937  -14.52543385] 510.73693945778564
# [-474.24534932  277.41272669  -14.91629118] 519.5924191010247
# [-487.5209313   292.18838211  -15.18985167] 528.1135049206991
# [-500.44557186  306.83924909  -15.34618622] 536.3195508914855
# [-512.49898044  321.33487446  -15.377631  ] 543.9268364786819
# [-524.03112956  335.68199486  -15.29405463] 551.1508268896945
# [-535.1792978   349.89007879  -15.10147702] 558.0968481794048
# [-545.93992431  363.96162325  -14.80424116] 564.7886821224681
# [-556.07983625  377.84873705  -14.40460908] 571.0811547881283
# [-564.93360938  391.40898352  -13.90124798] 576.5074141835137
# [-573.41120168  403.2135837   -13.32094817] 580.4085456907108
# [-581.45308707  413.84100773  -12.6674999 ] 583.2657509710175
# [-589.03263483  423.93641045  -11.94544331] 585.6280390478487
# [-595.6021718   433.5778192   -11.15723454] 587.2707677430569
# [-600.80518836  442.83258365  -10.3087086 ] 588.0582501361047
# [-605.55631863  451.56411537   -9.41868417] 588.4272445536645
# [-609.85129657  459.76926028   -8.49554628] 588.3985481490697
# [-613.68665432  467.44550477   -7.54759968] 587.993927272113
# [-616.85070413  474.60212046   -6.58136532] 587.118129393958
# [-618.19118536  481.31441062   -5.59645694] 585.1461648601052
# [-619.1145547   487.51580591   -4.61152913] 582.8924601140774
# [-619.62132418  493.20426516   -3.6335004 ] 580.3789381430117
# [-619.7118796   498.37815479   -2.66884173] 577.6275424311189
# [-619.38662898  503.03659379   -1.72352667] 574.6603699407424
# [-618.35592852  507.17651157   -0.80141332] 571.3100110318262
# [-6.15718443e+02  5.10801407e+02  9.71505784e-02] 567.0048125421774
# [-612.73541499  513.92928619    0.96081244] 562.5846815630489
# [-411.91763725  413.58965585   -8.51654991] 341.064419001334
# [-404.88734041  415.11787553   -8.0331215 ] 332.9165590974522
# [-397.4684891   416.10853522   -7.5456569 ] 324.5882480696941
# [-389.67497221  416.56048913   -7.05671047] 316.10501861081184
# [-381.52142221  416.47328282   -6.56875561] 307.4936677930811
# [-373.02330776  415.84727755   -6.08417818] 298.782509093382
# [-364.19690557  414.68360057   -5.60526682] 290.0014624836931
# [-355.05919946  412.98412799   -5.13420603] 281.18209463028955
# [-345.62802292  410.75147104   -4.67306841] 272.3579417617741
# [-335.92182997  407.9890311    -4.22381157] 263.5644904671033
# [-325.95992176  404.70085103   -3.78826873] 254.83954229974026
# [-315.7622536   400.89178142   -3.36814837] 246.2233025290175
# [-305.34949271  396.56729373   -2.96502574] 237.75859465744756
# [-294.7430187   391.73357172   -2.58034134] 229.49102354006422
# [-283.96492167  386.39747157   -2.21539563] 221.4691489817328
# [-273.03793357  380.56645682   -1.87134482] 213.74443751248822
# [-261.98550235  374.2486429    -1.54919803] 206.37123891757923
# [-250.83164151  367.45279746   -1.2498152 ] 199.4064206855313
# [-239.60106377  360.18826562   -0.97390092] 192.90888408912875
# [-228.19764098  352.63220825   -0.72679325] 186.92297689320336
# [-216.63631645  344.80724134   -0.50940813] 181.47336748607722
# [-2.05054318e+02  3.36569812e+02 -3.17591599e-01] 176.61374792588106
# [-1.93478076e+02  3.27930958e+02 -1.51369573e-01] 172.3891881047969
# [-1.81934386e+02  3.18902267e+02 -1.05963912e-02] 168.83899204357624
# [-1.70450380e+02  3.09495887e+02  1.05045492e-01] 165.99470834100717
# [-1.59053431e+02  2.99724489e+02  1.96044177e-01] 163.87813962899813
# [-1.47998192e+02  2.89572185e+02  2.68627191e-01] 162.71937172615685
# [-137.14149516  279.08516574    0.31974357] 162.36057150956583
# [-126.46204816  268.2857545     0.34921494] 162.73663082098642
# [-115.98139938  257.19912901    0.35793542] 163.81045633020852
# [-105.40369825  246.45382335    0.33313296] 165.1742781351196
# [-95.05849559 235.45733986   0.290506  ] 167.06309423100043
# [-84.96988098 224.22593179   0.23164816] 169.42675613204008
# [-7.51611396e+01  2.12776670e+02  1.58251195e-01] 172.21250413473624
# [-6.56545167e+01  2.01127455e+02  7.20881607e-02] 175.36645750379003
# [-5.64712373e+01  1.89297018e+02 -2.49985580e-02] 178.83513384973054
# [-4.76312698e+01  1.77305010e+02 -1.31114788e-01] 182.56628904140658
# [-39.04295099 165.49658842  -0.24791787] 186.29582580948318
# [-30.67519905 154.00053057  -0.37368541] 189.87158185619518
# [-22.68648771 142.40485366  -0.50119458] 193.52678815656822
# [-15.09177372 130.73059659  -0.62837242] 197.22718734481194
# [ -7.9045613  118.99972067  -0.75317149] 200.94093312597215
# [ -1.13690315 107.23493107  -0.87358285] 204.6385728871711
# [ 5.20058047 95.45974876 -0.9876465 ] 208.29296678985526
# [11.13423788 83.87389312 -1.09287653] 211.76904868442057
# [16.74246788 72.89300988 -1.18492484] 214.78791214356687
# [21.90552513 61.96161263 -1.2632316 ] 217.68898995969357
# [26.61739092 51.10360497 -1.32615251] 220.45845920128048
# [30.87338091 40.34318129 -1.37216715] 223.084012535762
# [34.6700515  29.70479606 -1.39988708] 225.55490195499252
# [38.00526399 19.21294854 -1.40807096] 227.861944187942
# [40.8779818   8.89218256 -1.3956279 ] 229.99752971756283
# [43.28830824 -1.23315069 -1.36163196] 231.955773217597
# [ 45.28209257 -10.57811509  -1.29305277] 233.45019220108995
# [ 46.81980389 -19.67805493  -1.1998945 ] 234.76718648746305
# [ 47.32996001 -28.44685853  -1.06340879] 236.40739863905563
# [ 47.30498188 -36.93672255  -0.90064113] 237.96769474518032
# [ 46.79417181 -45.13362128  -0.7135616 ] 239.41728465274613
# [ 45.80365593 -53.01750206  -0.50288975] 240.7641183010513
# [ 44.34040654 -60.56915647  -0.26958704] 242.01770201131444
# [ 4.24121715e+01 -6.77703336e+01 -1.48572331e-02] 243.1890878344608
# [ 40.02736726 -74.60381274   0.25985752] 244.29090000162435
# [ 37.19505896 -81.05338802   0.55288177] 245.33716503759598
# [ 33.92487254 -87.10395725   0.86231344] 246.3432954896122
# [ 30.22696168 -92.74154455   1.18603263] 247.3259455225185
# [ 26.11189689 -97.95328622   1.52171431] 248.30285405736197
# [  21.59069731 -102.72750818    1.86683906] 249.29266784811358
# [  16.67475569 -107.05368658    2.21871097] 250.31476032173498
# [  11.37575047 -110.92243552    2.57447482] 251.3889400158927
# [   5.70574126 -114.32559878    2.93113372] 252.53523914645857
# [  -0.32299811 -117.25615136    3.2855737 ] 253.77361113581506
# [  -6.69791023 -119.70823758    3.63458604] 255.12363692016228
# [ -13.40621159 -121.67714758    3.97489219] 256.60418508446486
# [ -20.43486229 -123.15933538    4.30317068] 258.2331047608281
# [ -27.7706691  -124.1523476     4.61608786] 260.026963768491
# [ -35.40018468 -124.65487607    4.91032251] 262.000636898263
# [ -43.30980296 -124.66669444    5.18260119] 264.1671597478734
# [ -51.48571344 -124.18864587    5.42972566] 266.53737348311574
# [ -59.91391481 -123.22264378    5.64860436] 269.11975021968703
# [ -68.58023368 -121.77166636    5.83628515] 271.92029177135703
# [ -77.47032107 -119.83968424    5.98998322] 274.94230507998833
# [ -86.56965373 -117.4316505     6.10711296] 278.1864268792048
# [ -95.8635215  -114.55355162    6.18531414] 281.6505664439418
# [-105.33700801 -111.21228348    6.22248197] 285.32996960891177
# [-114.97506792 -107.41571384    6.21678885] 289.2172901010996
# [-124.76245831 -103.17257847    6.16671081] 293.30274120860776
# [-134.68375127  -98.49252888    6.07104526] 297.57422013862595
# [-144.72334892  -93.3860909     5.92892995] 302.01752039513303
# [-154.86547002  -87.86455636    5.73985858] 306.6165267322967
# [-165.09417173  -81.94011318    5.50369067] 311.3534670803096
# [-175.39333412  -75.6256745     5.22065939] 316.209065152293
# [-185.74666374  -68.93490725    4.89137807] 321.162845611735
# [-196.15338252  -61.77323168    4.51984872] 326.27212581586747
# [-206.64746055  -53.83141529    4.11536763] 331.7638957533972
# [-217.15492215  -45.54349165    3.6673441 ] 337.321709208999
# [-227.65896079  -36.92694718    3.17772392] 342.9201450657277
# [-238.14256962  -27.99986027    2.64881379] 348.53339204144794
# [-248.5885949   -18.78086635    2.08326649] 354.1355309791302
# [-258.97975695   -9.28916674    1.48405817] 359.70068309982037
# [-269.29858135    0.45558535    0.85446509] 365.20307952624034
# [-2.79527556e+02  1.04332321e+01  1.98035505e-01] 370.6173537836012
# [-289.6490073    20.6232576    -0.48143981] 375.91851476636623
# [-299.64526903   31.00468384   -1.17996343] 381.0821652738341
# [-309.50061647   41.61074647   -1.89257071] 386.12804114368896
# [-319.22145287   52.94831759   -2.60839758] 391.46487358051303
# [-328.77140688   64.41744287   -3.33241166] 396.6144003019869
# [-338.13261478   75.99506761   -4.06014791] 401.5528679159
# [-347.28723547   87.65804154   -4.78710373] 406.2575302146449
# [-356.27683095   99.2948191    -5.51140523] 410.66835522156424
# [-365.10210283  110.84643865   -6.22903559] 414.74219058538904
# [-373.61695684  122.48153659   -6.92994283] 418.5439033792554
# [-381.80621533  134.17993308   -7.61023983] 422.0618983678143
# [-389.65521835  145.92135033   -8.26622657] 425.28548408142206
# [-397.15011401  157.70663373   -8.89438619] 428.2228615255492
# [-404.28664939  169.91318023   -9.49151417] 431.20926843020357
# [-411.04398372  182.0963252   -10.05571308] 433.8742188221843
# [-417.40904938  194.23555663  -10.58419447] 436.20936805914675
# [-423.36945248  206.31046376  -11.07446673] 438.20739319359507
# [-429.07315114  217.98070867  -11.52751537] 439.6631530721529
# [-434.38171289  229.45905969  -11.93788442] 440.70615200501527
# [-439.28188893  240.72434359  -12.30365216] 441.3286753076323
# [-443.76106544  251.7560024   -12.62324872] 441.52447395117304
# [-447.80745872  262.53398618  -12.89546255] 441.28877422357124
# [-451.41007866  273.03900799  -13.11944261] 440.6183074789052
# [-454.43892261  283.54222694  -13.29466138] 439.71000172982826
# [-456.92965531  293.92583317  -13.42194283] 438.49855854716225
# [-458.95694894  303.97359357  -13.50166671] 436.8487226251598
# [-460.51337633  313.66844205  -13.53426194] 434.7616950684669
# [-461.59261014  322.99411474  -13.52047163] 432.24018754394933
# [-462.18932865  331.93518651  -13.46133414] 429.2883380075364
# [-462.29923266  340.47715554  -13.35816429] 425.9117877005346
# [-461.91918433  348.60629606  -13.21253339] 422.11750571948625
# [-461.04714804  356.30983771  -13.0262474 ] 417.9139182887056
# [-459.68221075  363.57585689  -12.80132248] 413.3107598031562
# [-457.82463837  370.39331453  -12.5399622 ] 408.319078389777
# [-455.47581181  376.7520291   -12.24453172] 402.95117496068127
# [-452.63825747  382.64271931  -11.91753472] 397.2206366383063
# [-449.27784281  388.1067849   -11.56200955] 391.1682151838624
# [-445.27832411  393.29810456  -11.18238605] 384.8934202031839
# [-440.81927568  397.98237068  -10.77970789] 378.2938107749715
# [-435.90783959  402.15282508  -10.3567053 ] 371.38653079533736
# [-430.55225035  405.80352754   -9.91613432] 364.1899348012661
# [-424.76173001  408.92932609   -9.46075634] 356.72346507972105
# [-418.54645447  411.52588164   -8.99332082] 349.0076940408202
# Calculation executed!
# Total run time: 13.02602505683899 seconds
